# %% [markdown]
# <a href="https://colab.research.google.com/github/ayomibamm/Vertical-Search-Engine/blob/main/Vertical_Search_Engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Robot.txt check**

# %% [markdown]
# https://pureportal.coventry.ac.uk/robots.txt:
#
# - User-Agent: *
#
# - Crawl-Delay: 5
#
# - Disallow: /*?*format=rss
#
# - Disallow: /*?*export=xls
#
# - Sitemap: https://pureportal.coventry.ac.uk/sitemap.xml

# %% [markdown]
# ## **Libraries importation**

# %%
import json
import string
import pandas as pd
import numpy as np
from time import sleep
from bs4 import BeautifulSoup as bs
import requests
from collections import Counter
import urllib.robotparser
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# RobotFileParser object to help read the url robots.txt file
rule_preservation = urllib.robotparser.RobotFileParser()
rule_preservation.set_url("https://pureportal.coventry.ac.uk/en/organisations/research-centre-for-computational-science-and-mathematical-modell/robots.txt")
rule_preservation.read()

# Ensuring that required url can be crawled
url = "https://pureportal.coventry.ac.uk/en/organisations/research-centre-for-computational-science-and-mathematical-modell/page.html"
if rule_preservation.can_fetch("*", url):
    print("Website crawling allowed")
else:
    print("Website crawling disallowed")
# Out:
# Website crawling allowed

# %% [markdown]
# ## **Web crawler processing**

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}

data =[]
aut_l = []

def getInfo(page):
    url = f'https://pureportal.coventry.ac.uk/en/organisations/research-centre-for-computational-science-and-mathematical-modell/publications/?page={page}&pagesize=50'
    response = requests.get(url, headers=headers)
    html = response.text
    soup = bs(html, "html.parser")
    box = soup.find_all('h3', class_='title')

    for dom in box:
        pub = {}
        title =dom.string.lower()   # extraction of publication title
        link = dom.find('a', class_ = 'link')
        links = link.get('href') # extraction of publication links

        html2 = requests.get(links)
        soup2 = bs(html2.text, 'html.parser') # application of beautiful soup module to each link to extract further information

        pub_abstract = soup2.find('div', class_ = 'textblock') # retrieving publication abstract

        if pub_abstract:
            abstracts = pub_abstract.text.strip()
            abstract = abstracts.partition('.')[0] + '...' # ensuring that only the first line of abstract is extracted
        else:
            abstract= "not available" # some of the publications do not have this information

        aut_details = soup2.find_all('a', class_ = 'link person')
        aut_data = []
        for author in aut_details:
            aut_name = author.get_text().strip() # authors name and link
            if aut_name:
                aut_names = aut_name
                aut_links = author.get('href')
                aut_l.append(aut_links)
                aut_data.append(f'{aut_names}, {aut_links}')

        pub_date = soup2.find('span', class_ = 'date').string.strip()

        if aut_data: # all information appended only if at least 1 author has both information present
            pub['Publication title'] = title
            pub['Link'] = links
            pub['Abstract'] = abstract
            pub['Date'] = pub_date
            pub['Author information'] = aut_data
            data.append(pub)

    return

# crawl delay of 5 seconds per page
for x in range(0,5):
    getInfo(x)
    sleep(5)

print(f'Total number of publication details with at least 1 co-author full details: {len(data)}')
print(f'Total number of publications per staff: {Counter(aut_l)}')
# Out:
# Total number of publication details with at least 1 co-author full details: 202
# Total number of publications per staff: Counter({'https://pureportal.coventry.ac.uk/en/persons/vasile-palade': 47, 'https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah': 37, 'https://pureportal.coventry.ac.uk/en/persons/alison-halford': 22, 'https://pureportal.coventry.ac.uk/en/persons/elena-gaura': 19, 'https://pureportal.coventry.ac.uk/en/persons/fei-he': 17, 'https://pureportal.coventry.ac.uk/en/persons/matthew-england': 17, 'https://pureportal.coventry.ac.uk/en/persons/james-brusey': 13, 'https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh': 11, 'https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon': 11, 'https://pureportal.coventry.ac.uk/en/persons/sariya-cheruvallil-contractor': 9, 'https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang': 8, 'https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun': 8, 'https://pureportal.coventry.ac.uk/en/persons/seongki-yoo': 8, 'https://pureportal.coventry.ac.uk/en/persons/yingliang-ma': 7, 'https://pureportal.coventry.ac.uk/en/persons/dominik-klepl': 6, 'https://pureportal.coventry.ac.uk/en/persons/server-kasap': 6, 'https://pureportal.coventry.ac.uk/en/persons/matthew-stephen-tart': 4, 'https://pureportal.coventry.ac.uk/en/persons/heaven-crawley': 4, 'https://pureportal.coventry.ac.uk/en/persons/ming-lim': 4, 'https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano': 4, 'https://pureportal.coventry.ac.uk/en/persons/ibnu-febry-kurniawan': 4, 'https://pureportal.coventry.ac.uk/en/persons/azadeh-montazami': 4, 'https://pureportal.coventry.ac.uk/en/persons/majdi-fanous': 3, 'https://pureportal.coventry.ac.uk/en/persons/huma-shah': 3, 'https://pureportal.coventry.ac.uk/en/persons/ammar-al-bazi': 3, 'https://pureportal.coventry.ac.uk/en/persons/ankur-deo': 3, 'https://pureportal.coventry.ac.uk/en/persons/nadjim-horri': 3, 'https://pureportal.coventry.ac.uk/en/persons/sara-sharifzadeh': 3, 'https://pureportal.coventry.ac.uk/en/persons/stavros-christopoulos': 3, 'https://pureportal.coventry.ac.uk/en/persons/laura-roden': 2, 'https://pureportal.coventry.ac.uk/en/persons/jonathan-eden': 2, 'https://pureportal.coventry.ac.uk/en/persons/maria-tariq': 2, 'https://pureportal.coventry.ac.uk/en/persons/rashid-barket': 2, 'https://pureportal.coventry.ac.uk/en/persons/fatma-benkhelifa': 2, 'https://pureportal.coventry.ac.uk/en/persons/rjaa-jawad-ashraf': 2, 'https://pureportal.coventry.ac.uk/en/persons/michael-fitzpatrick': 2, 'https://pureportal.coventry.ac.uk/en/persons/miao-lin-pay': 1, 'https://pureportal.coventry.ac.uk/en/persons/jesper-christensen': 1, 'https://pureportal.coventry.ac.uk/en/persons/sivasharmini-ganeshamoorthy': 1, 'https://pureportal.coventry.ac.uk/en/persons/shenal-rajintha-alexander-samarathunge-gunawardena': 1, 'https://pureportal.coventry.ac.uk/en/persons/pengpeng-hu': 1, 'https://pureportal.coventry.ac.uk/en/persons/michael-ajao-olarinoye': 1, 'https://pureportal.coventry.ac.uk/en/persons/maryam-azizsafaei': 1, 'https://pureportal.coventry.ac.uk/en/persons/anup-pandey-2': 1, 'https://pureportal.coventry.ac.uk/en/persons/abiola-babatunde': 1, 'https://pureportal.coventry.ac.uk/en/persons/brandi-jo-jess': 1, 'https://pureportal.coventry.ac.uk/en/persons/beate-grawemeyer': 1, 'https://pureportal.coventry.ac.uk/en/persons/john-halloran': 1, 'https://pureportal.coventry.ac.uk/en/persons/james-donnelly': 1, 'https://pureportal.coventry.ac.uk/en/persons/james-shuttleworth': 1, 'https://pureportal.coventry.ac.uk/en/persons/abhiram-thiruthummal': 1, 'https://pureportal.coventry.ac.uk/en/persons/e-j-kim': 1, 'https://pureportal.coventry.ac.uk/en/persons/mohammed-ahmed': 1, 'https://pureportal.coventry.ac.uk/en/persons/faye-mitchell': 1, 'https://pureportal.coventry.ac.uk/en/persons/kathryn-stamp': 1, 'https://pureportal.coventry.ac.uk/en/persons/jaimz-winter': 1, 'https://pureportal.coventry.ac.uk/en/persons/seyed-mousavi-mousavi': 1, 'https://pureportal.coventry.ac.uk/en/persons/anuradha-herath': 1, 'htt ...

# %%
data
# Out:
# [{'Publication title': 'an extended plant circadian clock model for characterising flowering time under different light quality conditions',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-extended-plant-circadian-clock-model-for-characterising-flower',
#   'Abstract': 'Speed breeding has recently emerged as an innovative agricultural technology solution to meet the ever-increasing global food demand...',
#   'Date': '9 Jan 2023',
#   'Author information': ['Miao Lin Pay, https://pureportal.coventry.ac.uk/en/persons/miao-lin-pay',
#    'Jesper Christensen, https://pureportal.coventry.ac.uk/en/persons/jesper-christensen',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he',
#    'Laura Roden, https://pureportal.coventry.ac.uk/en/persons/laura-roden']},
#  {'Publication title': 'challenges and prospects of climate change impact assessment on mangrove environments through mathematical models',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/challenges-and-prospects-of-climate-change-impact-assessment-on-m',
#   'Abstract': 'The impacts of climate change, especially sea-level rise, are an increasing threat to the world’s coastal regions...',
#   'Date': '25 Feb 2023',
#   'Author information': ['Majdi Fanous, https://pureportal.coventry.ac.uk/en/persons/majdi-fanous',
#    'Jonathan Eden, https://pureportal.coventry.ac.uk/en/persons/jonathan-eden',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'diabetic retinopathy detection using transfer and reinforcement learning with effective image preprocessing and data augmentation techniques',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/diabetic-retinopathy-detection-using-transfer-and-reinforcement-l',
#   'Abstract': 'Diabetic retinopathy is the consequence of advanced stages of diabetes, which can ultimately lead to permanent blindness...',
#   'Date': '7 Feb 2023',
#   'Author information': ['Maria Tariq, https://pureportal.coventry.ac.uk/en/persons/maria-tariq',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade',
#    'YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  {'Publication title': 'entropy‐based lamarckian quantum‐behaved particle swarm optimization for flexible ligand docking',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/entropybased-lamarckian-quantumbehaved-particle-swarm-optimizatio',
#   'Abstract': 'AutoDock is a widely used software for flexible ligand docking problems since it is open source and easy to be implemented...',
#   'Date': '31 Jan 2023',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'extracting the evolutionary backbone of scientific domains: the semantic main path network approach based on citation context analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/extracting-the-evolutionary-backbone-of-scientific-domains-the-se',
#   'Abstract': 'Main path analysis is a popular method for extracting the scientific backbone from the citation network of a research domain...',
#   'Date': '15 Feb 2023',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  {'Publication title': 'gene regulatory network inference through link prediction using graph neural network',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/gene-regulatory-network-inference-through-link-prediction-using-g',
#   'Abstract': 'Gene Regulatory Networks (GRNs) depict the causal regulatory interactions between transcription factors (TFs) and their target genes [2], where TFs are proteins that regulate gene transcription...',
#   'Date': '19 Jan 2023',
#   'Author information': ['Sivasharmini Ganeshamoorthy, https://pureportal.coventry.ac.uk/en/persons/sivasharmini-ganeshamoorthy',
#    'Laura Roden, https://pureportal.coventry.ac.uk/en/persons/laura-roden',
#    'Dominik Klepl, https://pureportal.coventry.ac.uk/en/persons/dominik-klepl',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  {'Publication title': 'hydro-morphodynamic modelling of mangroves imposed by tidal waves using finite element discontinuous galerkin method',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/hydro-morphodynamic-modelling-of-mangroves-imposed-by-tidal-waves',
#   'Abstract': 'Modelling the hydro-morphodynamics of mangrove environments is key for implementing successful protection and restoration projects in a climatically vulnerable region...',
#   'Date': '21 Mar 2023',
#   'Author information': ['Majdi Fanous, https://pureportal.coventry.ac.uk/en/persons/majdi-fanous',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah',
#    'Jonathan M. Eden, https://pureportal.coventry.ac.uk/en/persons/jonathan-eden',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': "kernel-based nonlinear manifold learning for eeg functional connectivity analysis with application to alzheimer's disease",
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/kernel-based-nonlinear-manifold-learning-for-eeg-functional-conne',
#   'Abstract': 'Dynamical, causal and cross-frequency coupling analysis using the EEG has received significant interest for the analysis and diagnosis of neurological disorders [1]–[3]...',
#   'Date': '19 Jan 2023',
#   'Author information': ['Shenal Rajintha Alexander Samarathunge Gunawardena, https://pureportal.coventry.ac.uk/en/persons/shenal-rajintha-alexander-samarathunge-gunawardena',
#    'F. He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  {'Publication title': 'not born of woman: gendered robots',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/not-born-of-woman-gendered-robots',
#   'Abstract': "This chapter posits that gender, while being messy and non-binary, is a salient consideration in the development of virtual and embodied robots to avoid replicating stereotypical representations of men and women's roles and occupations in our future artificial work colleagues, and companions...",
#   'Date': '26 Feb 2023',
#   'Author information': ['Huma Shah, https://pureportal.coventry.ac.uk/en/persons/huma-shah']},
#  {'Publication title': 'posenormnet: identity-preserved posture normalization of 3d body scans in arbitrary postures',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/posenormnet-identity-preserved-posture-normalization-of-3d-body-s',
#   'Abstract': '3D human models accurately represent the shape of the subjects, which is key to many human-centric industrial applications, including fashion design, body biometrics extraction, and computer animation...',
#   'Date': '16 Feb 2023',
#   'Author information': ['Pengpeng Hu, https://pureportal.coventry.ac.uk/en/persons/pengpeng-hu']},
#  {'Publication title': 'unidirectional migration of populations with allee effect',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/unidirectional-migration-of-populations-with-allee-effect',
#   'Abstract': 'In this note we consider two populations living on identical patches, connected by unidirectional migration, and subject to strong Allee effect...',
#   'Date': '10 Jan 2023',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh',
#    'AmirHosein Sadeghimanesh Sadeghi Manesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  {'Publication title': 'xdll: explained deep learning lidar-based localization and mapping method for self-driving vehicles',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/xdll-explained-deep-learning-lidar-based-localization-and-mapping',
#   'Abstract': 'Self-driving vehicles need a robust positioning system to continue the revolution in intelligent transportation...',
#   'Date': '22 Jan 2023',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'a community energy management system for smart microgrids',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/a-community-energy-management-system-for-smart-microgrids',
#   'Abstract': 'Community micro-grid energy projects are needed to drive de-carbonisation and increase equity of energy systems among displaced communities...',
#   'Date': '9 Apr 2022',
#   'Author information': ['Jonathan Daniel Nixon, https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford']},
#  {'Publication title': 'a hybrid linear iterative clustering and bayes classification-based grabcut segmentation scheme for dynamic detection of cervical cancer',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/a-hybrid-linear-iterative-clustering-and-bayes-classification-bas',
#   'Abstract': 'Cervical cancer earlier detection remains indispensable for enhancing the survival rate probability among women patients worldwide...',
#   'Date': '18 Oct 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'allocating medical resources (vaccine) to control a pandemic',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/allocating-medical-resources-vaccine-to-control-a-pandemic',
#   'Abstract': 'In the aftermath of the COVID-19 pandemic, we need to better understand how to prepare for other pandemics in the future...',
#   'Date': '26 Apr 2022',
#   'Author information': ['Michael Ajao-Olarinoye, https://pureportal.coventry.ac.uk/en/persons/michael-ajao-olarinoye']},
#  {'Publication title': 'an agent-based optimisation approach for vehicle routing problem with unique vehicle location and depot',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-agent-based-optimisation-approach-for-vehicle-routing-problem-',
#   'Abstract': 'The Vehicle Routing Problem (VRP) is a well studied logistical problem along with its various variants such as VRP with customer Time-Window (VRPTW)...',
#   'Date': '20 Dec 2021',
#   'Author information': ['Ammar Al Bazi, https://pureportal.coventry.ac.uk/en/persons/ammar-al-bazi',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'an effective swarm intelligence optimization algorithm for flexible ligand docking',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-effective-swarm-intelligence-optimization-algorithm-for-flexib',
#   'Abstract': 'In general, flexible ligand docking is used for docking simulations under the premise that the position of the binding site is already known, and meanwhile, it can also be used without prior knowledge of the binding site...',
#   'Date': '10 Aug 2021',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'an improved gaussian distribution based quantum-behaved particle swarm optimization algorithm for engineering shape design problems',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-improved-gaussian-distribution-based-quantum-behaved-particle-',
#   'Abstract': 'In this article, an improved Gaussian distribution based quantum-behaved particle swarm optimization (IG-QPSO) algorithm is proposed to solve engineering shape design problems with multiple constraints...',
#   'Date': '23 Mar 2021',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'an integrated framework for diagnosing process faults with incomplete features',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-integrated-framework-for-diagnosing-process-faults-with-incomp',
#   'Abstract': 'Handling missing values and large-dimensional features are crucial requirements for data-driven fault diagnosis systems...',
#   'Date': '26 Nov 2021',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'an smt solver for non-linear real arithmetic inside maple',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-smt-solver-for-non-linear-real-arithmetic-inside-maple-2',
#   'Abstract': 'We report on work-in-progress to create an SMT-solver inside Maple for non-linear real arithmetic (NRA)...',
#   'Date': '23 Nov 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'an smt solver for non-linear real arithmetic inside maple',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-smt-solver-for-non-linear-real-arithmetic-inside-maple',
#   'Abstract': 'not available',
#   'Date': '6 Jul 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'artificial intelligence in cars: how close yet far are we from fully autonomous vehicles?',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/artificial-intelligence-in-cars-how-close-yet-far-are-we-from-ful',
#   'Abstract': 'In the last several years, strides in Artificial Intelligence (AI) have allowed for substantial developments in autonomous driving...',
#   'Date': '3 May 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade',
#    'Ankur Deo, https://pureportal.coventry.ac.uk/en/persons/ankur-deo']},
#  {'Publication title': 'assessing risks in dairy supply chain systems: a system dynamics approach',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/assessing-risks-in-dairy-supply-chain-systems-a-system-dynamics-a',
#   'Abstract': 'Due to the dynamic nature of the food supply chain system, food supply management could suffer because of, and be interrupted by, unforeseen events...',
#   'Date': '4 Aug 2022',
#   'Author information': ['Maryam Azizsafaei, https://pureportal.coventry.ac.uk/en/persons/maryam-azizsafaei',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': "bispectrum-based cross-frequency functional connectivity: classification of alzheimer's disease",
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/bispectrum-based-cross-frequency-functional-connectivity-classifi',
#   'Abstract': 'Alzheimer’s disease (AD) is a neurodegenerative disease known to affect brain functional connectivity (FC)...',
#   'Date': '8 Sep 2022',
#   'Author information': ['Dominik Klepl, https://pureportal.coventry.ac.uk/en/persons/dominik-klepl',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  {'Publication title': 'brain tumor classification using a combination of variational autoencoders and generative adversarial networks',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/brain-tumor-classification-using-a-combination-of-variational-aut',
#   'Abstract': 'Brain tumors are a pernicious cancer with one of the lowest five-year survival rates...',
#   'Date': '21 Jan 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'cell site analysis; changes to networks with time',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/cell-site-analysis-changes-to-networks-with-time',
#   'Abstract': 'Cell service areas may change over time as sites or cells are adjusted, decommissioned or introduced, and there may have been changes between the time of calls and the analysis undertaken...',
#   'Date': '6 Apr 2022',
#   'Author information': ['Matthew Stephen Tart, https://pureportal.coventry.ac.uk/en/persons/matthew-stephen-tart']},
#  {'Publication title': 'characterising alzheimers disease with eeg-based energy landscape analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/characterising-alzheimers-disease-with-eeg-based-energy-landscape-2',
#   'Abstract': "Alzheimer's disease (AD) is one of the most common neurodegenerative diseases, with around 50 million patients worldwide...",
#   'Date': '18 Aug 2021',
#   'Author information': ['Dominik Klepl, https://pureportal.coventry.ac.uk/en/persons/dominik-klepl',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  {'Publication title': 'clogs and shawls: mormons, moorlands, and the search for zion',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/clogs-and-shawls-mormons-moorlands-and-the-search-for-zion',
#   'Abstract': 'not available',
#   'Date': '31 Jan 2022',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford']},
#  {'Publication title': 'comparative graph-based summarization of scientific papers guided by comparative citations',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/comparative-graph-based-summarization-of-scientific-papers-guided',
#   'Abstract': 'With the rapid growth of scientific papers, understanding the changes and trends in a research area is rather time-consuming...',
#   'Date': 'Oct 2022',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  {'Publication title': 'comparing the behaviour of two topic-modelling algorithms in covid-19 vaccination tweets',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/comparing-the-behaviour-of-two-topic-modelling-algorithms-in-covi',
#   'Abstract': 'Coronavirus is a newly developed infectious disease that has triggered a pandemic due to its ease of transmission as of early 2020...',
#   'Date': 'Jan 2022',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'contextualised segment-wise citation function classification',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/contextualised-segment-wise-citation-function-classification',
#   'Abstract': 'Much effort has been made in the past decades to citation function classification...',
#   'Date': '2022',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  {'Publication title': 'convolution neural networks for pothole detection of critical road infrastructure',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/convolution-neural-networks-for-pothole-detection-of-critical-roa',
#   'Abstract': 'A well developed and maintained highway infrastructure is essential for the economic and social prosperity of modern societies...',
#   'Date': '16 Feb 2022',
#   'Author information': ['Anup Kumar Pandey, https://pureportal.coventry.ac.uk/en/persons/anup-pandey-2',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'data-driven dynamical modelling of a pathogen-infected plant gene regulatory network: a comparative analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/data-driven-dynamical-modelling-of-a-pathogen-infected-plant-gene',
#   'Abstract': 'Recent advances in synthetic biology have enabled the design of genetic feedback control circuits that could be implemented to build resilient plants against pathogen attacks...',
#   'Date': '1 Jul 2022',
#   'Author information': ['Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  {'Publication title': 'detection of sleep apnea using machine learning algorithms based on ecg signals: a comprehensive systematic review',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/detection-of-sleep-apnea-using-machine-learning-algorithms-based-',
#   'Abstract': 'Sleep apnea (SA) is a common sleep disorder that is not easy to detect...',
#   'Date': '25 Sep 2021',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'differential radial basis function network for sequence modelling',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/differential-radial-basis-function-network-for-sequence-modelling',
#   'Abstract': 'We propose a differential radial basis function (RBF) network termed RBF-DiffNet—whose hidden layer blocks are partial differential equations (PDEs) linear in terms of the RBF—to make the baseline RBF network robust to noise in sequential data...',
#   'Date': '13 Oct 2021',
#   'Author information': ['James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura']},
#  {'Publication title': 'edge-enhancement densenet for x-ray fluoroscopy image denoising in cardiac electrophysiology procedures',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/edge-enhancement-densenet-for-x-ray-fluoroscopy-image-denoising-i',
#   'Abstract': 'Purpose: Reducing X-ray dose increases safety in cardiac electrophysiology procedures but also increases image noise and artifacts which may affect the discernibility of devices and anatomical cues...',
#   'Date': '18 Jan 2022',
#   'Author information': ['YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  {'Publication title': "eeg-based graph neural network classification of alzheimer's disease: an empirical evaluation of functional connectivity methods",
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/eeg-based-graph-neural-network-classification-of-alzheimers-disea',
#   'Abstract': "Alzheimer's disease (AD) is the leading form of dementia worldwide...",
#   'Date': '6 Sep 2022',
#   'Author information': ['Dominik Klepl, https://pureportal.coventry.ac.uk/en/persons/dominik-klepl',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  {'Publication title': 'efficacy of covid-19 vaccines by race and ethnicity',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/efficacy-of-covid-19-vaccines-by-race-and-ethnicity',
#   'Abstract': 'Objectives: Vaccine uptake amongst ethnic minority populations has been persistently lower, which may be because of socio-economic factors such as health literacy and health insurance status...',
#   'Date': '5 May 2022',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'examining type 1 diabetes mathematical models using experimental data',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/examining-type-1-diabetes-mathematical-models-using-experimental-',
#   'Abstract': 'Type 1 diabetes requires treatment with insulin injections and monitoring glucose levels in affected individuals...',
#   'Date': '10 Jan 2022',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'exploiting domain structures in heuristic algorithms for the set covering problem: a literature review',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/exploiting-domain-structures-in-heuristic-algorithms-for-the-set-',
#   'Abstract': 'This review aims at understanding the set covering problem (SCP) as an NP-hard problem, the variants of SCP, the methods that have been proposed to solve the problem, and gaps in the existing solutions that have been provided which need further research...',
#   'Date': '1 Apr 2022',
#   'Author information': ['Abiola Babatunde, https://pureportal.coventry.ac.uk/en/persons/abiola-babatunde']},
#  {'Publication title': 'exploring dynamical properties of a type 1 diabetes model using sensitivity approaches',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/exploring-dynamical-properties-of-a-type-1-diabetes-model-using-s',
#   'Abstract': 'The high global prevalence of diabetes, and the extortionate costs imposed on healthcare providers necessitate further research to understand different perspectives of the disease...',
#   'Date': '18 May 2022',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'fast, detailed, accurate simulation of a thermal car-cabin using machine-learning',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/fast-detailed-accurate-simulation-of-a-thermal-car-cabin-using-ma',
#   'Abstract': 'Car-cabin thermal systems, including heated seats, air-conditioning, and radiant panels, use a large proportion of the energy budget of electric vehicles and thus reduce their effective range...',
#   'Date': '10 Mar 2022',
#   'Author information': ['Brandi Jo Jess, https://pureportal.coventry.ac.uk/en/persons/brandi-jo-jess',
#    'James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura']},
#  {'Publication title': 'feedback and engagement on an introductory programming module',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/feedback-and-engagement-on-an-introductory-programming-module',
#   'Abstract': 'We ran a study on engagement and achievement for a first year undergraduate programming module which  used an online learning environment containing tasks which generate automated feedback...',
#   'Date': '6 Jan 2022',
#   'Author information': ['Beate Grawemeyer, https://pureportal.coventry.ac.uk/en/persons/beate-grawemeyer',
#    'John Halloran, https://pureportal.coventry.ac.uk/en/persons/john-halloran',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'framework for generating integrable expressions',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/framework-for-generating-integrable-expressions',
#   'Abstract': 'Applications of machine learning are becoming more prominent in the field of computer algebra...',
#   'Date': '2 Nov 2022',
#   'Author information': ['Rashid Barket, https://pureportal.coventry.ac.uk/en/persons/rashid-barket']},
#  {'Publication title': 'from theory to practice: a review of co-design methods for humanitarian energy ecosystems',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/from-theory-to-practice-a-review-of-co-design-methods-for-humanit',
#   'Abstract': 'Our planet is currently in the midst of a global humanitarian crisis...',
#   'Date': '23 Feb 2022',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Gaura, E., https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Crawley, H., https://pureportal.coventry.ac.uk/en/persons/heaven-crawley',
#    'Lim, M., https://pureportal.coventry.ac.uk/en/persons/ming-lim',
#    'Nixon, J., https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon']},
#  {'Publication title': 'gaussian process emulation of spatio-temporal outputs of a 2d inland flood model',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/gaussian-process-emulation-of-spatio-temporal-outputs-of-a-2d-inl',
#   'Abstract': 'The computational limitations of complex numerical models have led to adoption of statistical emulators across a variety of problems in science and engineering disciplines to circumvent the high computational costs associated with numerical simulations...',
#   'Date': '14 Sep 2022',
#   'Author information': ['James Donnelly, https://pureportal.coventry.ac.uk/en/persons/james-donnelly',
#    'Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'incorporating forecasting and peer-to-peer negotiation frameworks into a distributed model predictive control approach for meshed electric networks',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/incorporating-forecasting-and-peer-to-peer-negotiation-frameworks',
#   'Abstract': 'The continuous integration of renewable energy sources into power networks is causing a paradigm shift in energy generation and distribution with regard to trading and control...',
#   'Date': '15 Mar 2022',
#   'Author information': ['Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura']},
#  {'Publication title': 'kac-rice formulas and the number of solutions of parametrized systems of polynomial equations',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/kac-rice-formulas-and-the-number-of-solutions-of-parametrized-sys',
#   'Abstract': 'Kac-Rice formulas express the expected number of elements a fiber of a random field has in terms of a multivariate integral...',
#   'Date': '11 Aug 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  {'Publication title': 'levelwise construction of a single cylindrical algebraic cell',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/levelwise-construction-of-a-single-cylindrical-algebraic-cell',
#   'Abstract': 'Satisfiability Modulo Theories (SMT) solvers check the satisfiability of quantifier-free first-order logic formulas...',
#   'Date': '25 Nov 2022',
#   'Author information': ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'leveraging arabic sentiment classification using an enhanced cnn-lstm approach and effective arabic text preparation',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/leveraging-arabic-sentiment-classification-using-an-enhanced-cnn-',
#   'Abstract': 'The high variety in the forms of the Arabic words creates significant complexity related challenges in Natural Language Processing (NLP) tasks for Arabic text...',
#   'Date': '27 Dec 2021',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'lift: lncrna identification and function-prediction tool',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/lift-lncrna-identification-and-function-prediction-tool',
#   'Abstract': 'Long non-coding RNAs (lncRNAs) are a class of non-coding RNAs which play a significant role in several biological processes...',
#   'Date': '17 Jan 2022',
#   'Author information': ['James Shuttleworth, https://pureportal.coventry.ac.uk/en/persons/james-shuttleworth',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'machine learning for computer algebra',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/machine-learning-for-computer-algebra',
#   'Abstract': 'not available',
#   'Date': '2022',
#   'Author information': ['Rashid Barket, https://pureportal.coventry.ac.uk/en/persons/rashid-barket',
#    'Tereso del Río, https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'markov chain monte carlo-based estimation of stress–strength reliability parameter for generalized linear failure rate distributions',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/markov-chain-monte-carlo-based-estimation-of-stressstrength-relia',
#   'Abstract': 'This paper provides Bayesian and classical inference of Stress–Strength reliability parameter, [Formula: see text], where both [Formula: see text] and [Formula: see text] are independently distributed as 3-parameter generalized linear failure rate (GLFR) random variables with different parameters...',
#   'Date': '3 Jun 2021',
#   'Author information': ['A. Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'matrix decomposition by transforming the unit sphere to an ellipsoid through dilation, rotation and shearing',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/matrix-decomposition-by-transforming-the-unit-sphere-to-an-ellips',
#   'Abstract': 'There are various decompositions of matrices in the literature such as lower-upper, singular value and polar decompositions to name a few...',
#   'Date': '19 Oct 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  {'Publication title': 'minimizing age of information in multi-hop energy-harvesting wireless sensor network',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/minimizing-age-of-information-in-multi-hop-energy-harvesting-wire',
#   'Abstract': 'Age of information (AoI), a metric measuring the information freshness, has drawn increased attention due to its importance in monitoring applications in which nodes send time-stamped status updates to interested recipients, and timely updates about phenomena are important...',
#   'Date': '9 Aug 2022',
#   'Author information': ['Fatma Benkhelifa, https://pureportal.coventry.ac.uk/en/persons/fatma-benkhelifa']},
#  {'Publication title': 'monte carlo simulation of stochastic differential equation to study information geometry',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/monte-carlo-simulation-of-stochastic-differential-equation-to-stu',
#   'Abstract': 'Information Geometry is a useful tool to study and compare the solutions of a Stochastic Differential Equations (SDEs) for non-equilibrium systems...',
#   'Date': '12 Aug 2022',
#   'Author information': ['Abhiram Anand Thiruthummal, https://pureportal.coventry.ac.uk/en/persons/abhiram-thiruthummal',
#    'Eun-jin Kim, https://pureportal.coventry.ac.uk/en/persons/e-j-kim']},
#  {'Publication title': 'more than faith - muslim-heritage children in care: strategic briefing',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/more-than-faith-muslim-heritage-children-in-care-strategic-briefi',
#   'Abstract': 'This briefing aims to support senior managers in meeting the needs of Muslim-heritage children and young people in care...',
#   'Date': '31 May 2022',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
#    'Sariya Cheruvallil-Contractor, https://pureportal.coventry.ac.uk/en/persons/sariya-cheruvallil-contractor']},
#  {'Publication title': 'multi-phase locking value: a generalized method for determining instantaneous multi-frequency phase coupling',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/multi-phase-locking-value-a-generalized-method-for-determining-in-2',
#   'Abstract': 'Background: Many physical, biological and neural systems behave as coupled oscillators, with characteristic phase coupling across different frequencies...',
#   'Date': '7 Jan 2022',
#   'Author information': ['Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he',
#    'He, F., https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  {'Publication title': 'new heuristic to choose a cylindrical algebraic decomposition variable ordering motivated by complexity analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/new-heuristic-to-choose-a-cylindrical-algebraic-decomposition-var',
#   'Abstract': 'It is well known that the variable ordering can be critical to the efficiency or even tractability of the cylindrical algebraic decomposition (CAD) algorithm...',
#   'Date': '11 Aug 2022',
#   'Author information': ['Tereso del Río, https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'off the boil? the challenges of monitoring cooking behaviour in refugee settlements',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/off-the-boil-the-challenges-of-monitoring-cooking-behaviour-in-re',
#   'Abstract': 'To address the need for improved access to energy and meet the United Nations Clean Energy Challenge (2019), humanitarian agencies require robust, valid, and meaningful data that documents the everyday energy practices of displaced people...',
#   'Date': '22 Apr 2022',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Jonathan Nixon, https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon']},
#  {'Publication title': 'on the impact of prior distributions on efficiency of sparse gaussian process regression',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/on-the-impact-of-prior-distributions-on-efficiency-of-sparse-gaus',
#   'Abstract': 'Gaussian process regression (GPR) is a kernel-based learning model, which unfortunately suffers from computational intractability for irregular domain and large datasets due to the full kernel matrix...',
#   'Date': '26 Jun 2022',
#   'Author information': ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'on the implementation of cylindrical algebraic coverings for satisfiability modulo theories solving',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/on-the-implementation-of-cylindrical-algebraic-coverings-for-sati',
#   'Abstract': 'We recently presented cylindrical algebraic coverings: a method based on the theory of cylindrical algebraic decomposition and suited for nonlinear real arithmetic theory reasoning in Satisfiability Modulo Theories solvers...',
#   'Date': '10 Feb 2022',
#   'Author information': ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'on the scalability of duty-cycled lora networks with imperfect sf orthogonality',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/on-the-scalability-of-duty-cycled-lora-networks-with-imperfect-sf',
#   'Abstract': 'This letter uses stochastic geometry and queuing theory to study the scalability of long-range (LoRa) networks, accounting for duty cycling restrictions and imperfect spreading factor (SFs) orthogonality...',
#   'Date': '23 Aug 2022',
#   'Author information': ['Fatma Benkhelifa, https://pureportal.coventry.ac.uk/en/persons/fatma-benkhelifa']},
#  {'Publication title': 'parallel multi-swarm cooperative particle swarm optimization for protein–ligand docking and virtual screening',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/parallel-multi-swarm-cooperative-particle-swarm-optimization-for-',
#   'Abstract': 'Background: A high-quality docking method tends to yield multifold gains with half pains for the new drug development...',
#   'Date': '30 May 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'parts of speech tagging in nlp- an investigation on runtime optimization with quantum formulation and zx calculus',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/parts-of-speech-tagging-in-nlp-an-investigation-on-runtime-optimi',
#   'Abstract': 'This paper presents an optimized formulation of the parts of speech tagging in Natural Language Processing (NLP) with a quantum computing approach, and it further demonstrates the quantum gate-level runnable optimization with ZX-calculus, keeping the implementation target in the context of Noisy Intermediate Scale Quantum Systems (NISQ)...',
#   'Date': '10 Mar 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'polynomial superlevel set representation of the multistationarity region of chemical reaction networks',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/polynomial-superlevel-set-representation-of-the-multistationarity',
#   'Abstract': 'In this paper we introduce a new representation for the multistationarity region of a reaction network, using polynomial superlevel sets...',
#   'Date': '27 Sep 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'predicting primary sequence-based protein-protein interactions using a mercer series representation of nonlinear support vector machine',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/predicting-primary-sequence-based-protein-protein-interactions-us',
#   'Abstract': 'The prediction of protein-protein interactions (PPIs) is essential to understand the cellular processes from a medical perspective...',
#   'Date': '1 Dec 2022',
#   'Author information': ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'predicting the public adoption of connected and autonomous vehicles',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/predicting-the-public-adoption-of-connected-and-autonomous-vehicl',
#   'Abstract': 'Connected and Autonomous Vehicles (CAV) are gaining increasing importance due to the current needs of modern society for better mobility and societal impact...',
#   'Date': '11 Oct 2021',
#   'Author information': ['Mohammed Lawal Ahmed, https://pureportal.coventry.ac.uk/en/persons/mohammed-ahmed',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'privacy enhancing technologies (pets) for connected vehicles in smart cities',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/privacy-enhancing-technologies-pets-for-connected-vehicles-in-sma',
#   'Abstract': 'Many Experts believe that the Internet of Things (IoT) is a new revolution in technology that has brought many benefits for our organizations, businesses, and industries...',
#   'Date': '18 Nov 2020',
#   'Author information': ['Faye Mitchell, https://pureportal.coventry.ac.uk/en/persons/faye-mitchell']},
#  {'Publication title': 'rapid localization and mapping method based on adaptive particle filters',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/rapid-localization-and-mapping-method-based-on-adaptive-particle-',
#   'Abstract': 'With the development of autonomous vehicles, localization and mapping technologies have become crucial to equip the vehicle with the appropriate knowledge for its operation...',
#   'Date': '2 Dec 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'rdpsovina: the random drift particle swarm optimization for protein-ligand docking',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/rdpsovina-the-random-drift-particle-swarm-optimization-for-protei',
#   'Abstract': 'Protein-ligand docking is of great importance to drug design, since it can predict the binding affinity between ligand and protein, and guide the synthesis direction of the lead compounds...',
#   'Date': '9 May 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'resilient consensus control design for dc microgrids against false data injection attacks using a distributed bank of sliding mode observers',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/resilient-consensus-control-design-for-dc-microgrids-against-fals',
#   'Abstract': 'This paper investigates the problem of false data injection attack (FDIA) detection in microgrids...',
#   'Date': '30 Mar 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'saving research budgets by improving algebraic tools for the study of population dynamics',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/saving-research-budgets-by-improving-algebraic-tools-for-the-stud',
#   'Abstract': 'not available',
#   'Date': '7 Mar 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  {'Publication title': 'sc-square: future progress with machine learning',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/sc-square-future-progress-with-machine-learning',
#   'Abstract': 'The algorithms employed by our communities are often underspecified, and thus have multiple implementation choices, which do not effect the correctness of the output, but do impact the efficiency or even tractability of its production...',
#   'Date': '14 Nov 2022',
#   'Author information': ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'sc-square: overview to 2021.',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/sc-square-overview-to-2021',
#   'Abstract': 'This extended abstract was written to accompany an invited talk at the 2021 SC-Square Workshop, where the author was asked to give an overview of SC-Square progress to date...',
#   'Date': '14 Nov 2022',
#   'Author information': ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'stable likelihood computation for machine learning of linear differential operators with gaussian processes',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/stable-likelihood-computation-for-machine-learning-of-linear-diff',
#   'Abstract': 'In many applied sciences, the main aim is to learn the parameters in the operational equations which best fit the observed data...',
#   'Date': '20 Apr 2022',
#   'Author information': ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'switching trackers for effective sensor fusion in advanced driver assistance systems',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/switching-trackers-for-effective-sensor-fusion-in-advanced-driver',
#   'Abstract': 'Modern cars utilise Advanced Driver Assistance Systems (ADAS) in several ways...',
#   'Date': '3 Nov 2022',
#   'Author information': ['Ankur Deo, https://pureportal.coventry.ac.uk/en/persons/ankur-deo',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  {'Publication title': 'the benefits of clustering in cylindrical algebraic decomposition',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-benefits-of-clustering-in-cylindrical-algebraic-decomposition',
#   'Abstract': 'Cylindrical Algebraic Decomposition (CAD) is a very powerful algorithm with many potential applications, however, its doubly exponential complexity limits its usability...',
#   'Date': '2022',
#   'Author information': ['Tereso del Río, https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  {'Publication title': 'the politics of matching: ethnicity, religion and muslim-heritage children in care in the uk',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-politics-of-matching-ethnicity-religion-and-muslim-heritage-c',
#   'Abstract': 'In 2014, in order to improve outcomes for children from ethnic minority backgrounds and to speed up the adoption process, the UK government changed the Children and Families Act...',
#   'Date': '20 Apr 2022',
#   'Author information': ['Sariya Cheruvallil-Contractor, https://pureportal.coventry.ac.uk/en/persons/sariya-cheruvallil-contractor',
#    'Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
# ...
#  {'Publication title': 'opinion evidence in cell site analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/opinion-evidence-in-cell-site-analysis',
#   'Abstract': 'Issues concerning forensic inference exist in all areas of Forensic Science, and Cell Site Analysis is no exception...',
#   'Date': '26 Feb 2020',
#   'Author information': ['Matthew Stephen Tart, https://pureportal.coventry.ac.uk/en/persons/matthew-stephen-tart']},
#  {'Publication title': 'some computational considerations for kernel-based support vector machine',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/some-computational-considerations-for-kernel-based-support-vector',
#   'Abstract': 'Sometimes healthcare perspectives in communications technologies require data mining, especially classification as a supervised learning...',
#   'Date': '2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'the empty womb, the unanswered prayer: female infertility and involuntary childlessness in british mormon communities',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-empty-womb-the-unanswered-prayer-female-infertility-and-invol',
#   'Abstract': 'not available',
#   'Date': '28 Dec 2020',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford']},
#  {'Publication title': 'the impact of physical exercise on the fatigue symptoms in patients with multiple sclerosis: a systematic review and meta-analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-impact-of-physical-exercise-on-the-fatigue-symptoms-in-patien',
#   'Abstract': 'Background: Despite many benefits of the physical activity on physical and mental health of patients with Multiple Sclerosis (MS), the activity level in these patients is still very limited, and they continue to suffer from impairment in functioning ability...',
#   'Date': '13 Mar 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'the influence of acclimatization, age and gender-related differences on thermal perception in university buildings: case studies in scotland and england',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-influence-of-acclimatization-age-and-gender-related-differenc',
#   'Abstract': "The higher education sector in the UK is responsible for large amount of the country's energy consumption...",
#   'Date': '8 May 2020',
#   'Author information': ['James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Azadeh Montazami, https://pureportal.coventry.ac.uk/en/persons/azadeh-montazami',
#    'James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Azadeh Montazami, https://pureportal.coventry.ac.uk/en/persons/azadeh-montazami']},
#  {'Publication title': 'the prevalence of restless legs syndrome/willis-ekbom disease (rls/wed) in the third trimester of pregnancy: a systematic review',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-prevalence-of-restless-legs-syndromewillis-ekbom-disease-rlsw',
#   'Abstract': 'BACKGROUND: RLS is known as one of the most common movement disorders during pregnancy, which is most aggravated in the third trimester of pregnancy and can affect up to one-third of pregnant women...',
#   'Date': '13 Apr 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'the prevalence of severe depression in iranian older adult: a meta-analysis and meta-regression',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-prevalence-of-severe-depression-in-iranian-older-adult-a-meta',
#   'Abstract': 'Background: Depression is one of the most common psychiatric disorders in the older adult and one of the most common risk factors for suicide in the older adult...',
#   'Date': '3 Feb 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'the prevalence of sleep disturbances among physicians and nurses facing the covid-19 patients: a systematic review and meta-analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-prevalence-of-sleep-disturbances-among-physicians-and-nurses-',
#   'Abstract': 'Background: In all epidemics, healthcare staff are at the centre of risks and damages caused by pathogens...',
#   'Date': '29 Sep 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'the prevalence of stress, anxiety and depression within front-line healthcare workers caring for covid-19 patients: a systematic review and meta-regression',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-prevalence-of-stress-anxiety-and-depression-within-front-line',
#   'Abstract': 'Background Stress, anxiety, and depression are some of the most important research and practice challenges for psychologists, psychiatrists, and behavioral scientists...',
#   'Date': '17 Dec 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'understanding household fuel choice behaviour in the amazonas state, brazil: effects of validation and feature selection',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/understanding-household-fuel-choice-behaviour-in-the-amazonas-sta',
#   'Abstract': 'Since 2003, Brazil has striven to provide energy access to all, in rural areas, in an effort to economically empower the communities...',
#   'Date': '28 Jul 2020',
#   'Author information': ['Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Gaura, E., https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Brusey, J., https://pureportal.coventry.ac.uk/en/persons/james-brusey']},
#  {'Publication title': 'vehicular localisation at high and low estimation rates during gnss outages: a deep learning approach',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/vehicular-localisation-at-high-and-low-estimation-rates-during-gn',
#   'Abstract': 'Road localisation of autonomous vehicles is reliant on consistent accurate GNSS (Global Navigation Satellite System) positioning information...',
#   'Date': '25 Sep 2020',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade',
#    'Stavros Richard G. Christopoulos, https://pureportal.coventry.ac.uk/en/persons/stavros-christopoulos']},
#  {'Publication title': 'cell site analysis: roles and interpretation',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/cell-site-analysis-roles-and-interpretation',
#   'Abstract': 'This paper considers the confusion that exists between opinion and non-opinion evidence concerning telecommunication data – and thus the boundary between expert and technical evidence...',
#   'Date': '6 Jun 2019',
#   'Author information': ['Matthew Stephen Tart, https://pureportal.coventry.ac.uk/en/persons/matthew-stephen-tart']},
#  {'Publication title': 'mass transpiration in magneto-hydrodynamic boundary layer flow over a superlinear stretching sheet embedded in porous medium with slip',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/mass-transpiration-in-magneto-hydrodynamic-boundary-layer-flow-ov',
#   'Abstract': 'We have studied mass transpiration of a magneto-hydrodynamic (MHD) flow of a Newtonian fluid over a superlinear stretching sheet embedded in a porous medium...',
#   'Date': '1 Jan 2019',
#   'Author information': ['A. Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'remote sensing technologies and energy applications in refugee camps',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/remote-sensing-technologies-and-energy-applications-in-refugee-ca',
#   'Abstract': 'Whilst technological breakthroughs alone cannot revolutionise energy access for refugees, a number of innovations are offering the possibility of transformational change...',
#   'Date': '1 Jan 2019',
#   'Author information': ['Jonathan Daniel Nixon, https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Gaura, E., https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Crawley, H., https://pureportal.coventry.ac.uk/en/persons/heaven-crawley',
#    'Lim, M., https://pureportal.coventry.ac.uk/en/persons/ming-lim',
#    'Nixon, J., https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon']},
#  {'Publication title': 'spontaneous fruit fly optimisation for truss weight minimisation: performance evaluation based on the no free lunch theorem',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/spontaneous-fruit-fly-optimisation-for-truss-weight-minimisation-',
#   'Abstract': 'Over the past decade, several researchers have presented various optimisation algorithms for use in truss design...',
#   'Date': '24 Sep 2019',
#   'Author information': ['Michael E. Fitzpatrick, https://pureportal.coventry.ac.uk/en/persons/michael-fitzpatrick']},
#  {'Publication title': 'the scales project, a cross-national dataset on the interpretation of thermal perception scales',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-scales-project-a-cross-national-dataset-on-the-interpretation',
#   'Abstract': 'Thermal discomfort is one of the main triggers for occupants’ interactions with components of the built environment such as adjustments of thermostats and/or opening windows and strongly related to the energy use in buildings...',
#   'Date': '26 Nov 2019',
#   'Author information': ['Montazami Azadeh, https://pureportal.coventry.ac.uk/en/persons/azadeh-montazami']},
#  {'Publication title': 'algebraic tools in the study of multistationarity of chemical reaction networks',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/algebraic-tools-in-the-study-of-multistationarity-of-chemical-rea',
#   'Abstract': 'not available',
#   'Date': '31 Oct 2018',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  {'Publication title': 'among the last ones to leave? understanding the journeys of muslim children in the care system in england',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/among-the-last-ones-to-leave-understanding-the-journeys-of-muslim',
#   'Abstract': 'Children of Muslim heritage are likely to experience significant delay in finding a fostering or adoptive placement and where a child has complex needs due to health, disability, age, mixed or multiple heritage background or being part of a sibling group, finding permanent placement takes even longer...',
#   'Date': '2018',
#   'Author information': ['Sariya Cheruvallil-Contractor, https://pureportal.coventry.ac.uk/en/persons/sariya-cheruvallil-contractor',
#    'Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
#    'Cheruvallil-Contractor, S., https://pureportal.coventry.ac.uk/en/persons/sariya-cheruvallil-contractor',
#    'Halford, A., https://pureportal.coventry.ac.uk/en/persons/alison-halford']},
#  {'Publication title': 'discrete weighted exponential distribution of the second type: properties and applications',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/discrete-weighted-exponential-distribution-of-the-second-type-pro',
#   'Abstract': 'In this paper, we propose a new lifetime model as a discrete version of the continuous weighted exponential distribution which is called discrete weighted exponential distribution (DWED)...',
#   'Date': '2018',
#   'Author information': ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  {'Publication title': 'h*pt: 一种鼓励质量平衡产量的 h 型指数',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/hpt-an-h-type-index-encouraging-quality-and-balancing-productivit',
#   'Abstract': 'As a balanced indicator for both the quality and productivity of researchers’ scientific outputs, h-index suffers severely from loss of significant information in citation distributions so that its ability to discriminate researchers is rather limited...',
#   'Date': 'Jan 2017',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  {'Publication title': '基于城市群的空气质量数据的可视分析方法研究',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/urban-agglomerations-based-visual-analysis-of-air-quality-data',
#   'Abstract': 'Air pollution has gradually become an important issue, and has attracted more and more attention from the general public and the scientific community...',
#   'Date': '15 Mar 2017',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  {'Publication title': 'major differences of cloud computing adoption in universities: europe vs middle east',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/major-differences-of-cloud-computing-adoption-in-universities-eur-2',
#   'Abstract': 'The extensive use of cloud computing in educational institutes around the world brings unique challenges for universities...',
#   'Date': 'Dec 2014',
#   'Author information': ['Kevin Warwick, https://pureportal.coventry.ac.uk/en/persons/kevin-warwick']},
#  {'Publication title': 'extraction of cardiac and respiratory motion information from cardiac x-ray fluoroscopy images using hierarchical manifold learning',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/extraction-of-cardiac-and-respiratory-motion-information-from-car',
#   'Abstract': 'We present a novel and clinically useful method to automatically determine the regions that carry cardiac and respiratory motion information directly from standard mono-plane X-ray fluoroscopy images...',
#   'Date': '2013',
#   'Author information': ['YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  {'Publication title': 'infarct segmentation challenge on delayed enhancement mri of the left ventricle',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/infarct-segmentation-challenge-on-delayed-enhancement-mri-of-the-',
#   'Abstract': 'This paper presents collated results from the Delayed en-hancement MRI (DE-MRI) segmentation challenge as part of MICCAI 2012...',
#   'Date': '2013',
#   'Author information': ['YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  {'Publication title': 'real-time catheter extraction from 2d x-ray fluoroscopic and 3d echocardiographic images for cardiac interventions',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/real-time-catheter-extraction-from-2d-x-ray-fluoroscopic-and-3d-e',
#   'Abstract': 'X-ray fluoroscopic images are widely used for image guidance in cardiac electrophysiology (EP) procedures to diagnose or treat cardiac arrhythmias based on catheter ablation...',
#   'Date': '2013',
#   'Author information': ['YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  {'Publication title': 'adding logical operators to tree pattern queries ongraph-structured data',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/adding-logical-operators-to-tree-pattern-queries-ongraph-structur',
#   'Abstract': 'As data are increasingly modeled as graphs for expressing com-plex relationships, the tree pattern query on graph-structured databecomes an important type of queries in real-world applications...',
#   'Date': 'Aug 2012',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']}]

# %% [markdown]
# ## **Inverted Index implementation**

# %%
# data saved as a json data file
with open('publication.json', 'w') as f:
    json.dump(data, f)

publications = "/content/publication.json"

#function for inverted_index for the unique terms in the documents
ps = PorterStemmer()
def data_processing(publications):
    inverted_index={}
    cleaned_titles = []
    with open('publication.json', 'r') as f:
        publications = json.load(f)

    data_titles = [publication['Publication title'] for publication in publications]

    doc_id = 0

    # data pre-processing techniques application
    for titles in data_titles:
        tokenised_titles = word_tokenize(titles)
        tokenised_lower = [w.lower() for w in tokenised_titles if w.isalnum()]
        stopped_titles = [w for w in tokenised_lower if w not in stopwords.words('english')]
        stemmed_titles = [ps.stem(w) for w in stopped_titles]
        cleaned_titles.append(stemmed_titles)

        # initialisation of the indexer for each unique terms.
        for stemmed in stemmed_titles:
            value = inverted_index.get(stemmed)
            if value == None:
                count = [1, [doc_id]]
                inverted_index[stemmed] = count
            else:
                count = inverted_index[stemmed]
                if doc_id not in count[1]:
                    count[1].append(doc_id)
                    count[0] += 1

        doc_id += 1

    return inverted_index, cleaned_titles, data_titles

inverted_index, cleaned_titles, data_titles = data_processing(publications)

# %%
inverted_index
# Out:
# {'extend': [1, [0]],
#  'plant': [2, [0, 32]],
#  'circadian': [1, [0]],
#  'clock': [1, [0]],
#  'model': [17,
#   [0, 1, 6, 32, 34, 38, 40, 45, 46, 86, 95, 98, 99, 121, 148, 149, 174]],
#  'characteris': [3, [0, 26, 107]],
#  'flower': [1, [0]],
#  'time': [4, [0, 25, 102, 175]],
#  'differ': [3, [0, 180, 197]],
#  'light': [3, [0, 124, 171]],
#  'qualiti': [1, [0]],
#  'condit': [1, [0]],
#  'challeng': [5, [1, 59, 126, 145, 199]],
#  'prospect': [1, [1]],
#  'climat': [1, [1]],
#  'chang': [2, [1, 25]],
#  'impact': [3, [1, 60, 179]],
#  'assess': [5, [1, 22, 99, 164, 168]],
#  'mangrov': [3, [1, 6, 86]],
#  'environ': [6, [1, 86, 126, 127, 153, 168]],
#  'mathemat': [2, [1, 38]],
#  'diabet': [5, [2, 38, 40, 80, 148]],
#  'retinopathi': [2, [2, 80]],
#  'detect': [8, [2, 13, 31, 33, 82, 83, 92, 136]],
#  'use': [33,
#   [2,
#    5,
#    6,
#    24,
#    33,
#    38,
#    40,
#    41,
#    49,
#    66,
#    71,
#    82,
#    83,
#    84,
#    85,
#    86,
#    87,
#    105,
#    110,
#    113,
#    114,
#    118,
#    122,
#    126,
#    128,
#    141,
#    143,
#    152,
#    162,
#    167,
#    169,
#    170,
#    198]],
#  'transfer': [3, [2, 80, 120]],
#  'reinforc': [1, [2]],
#  'learn': [19,
#   [2,
#    7,
#    11,
#    33,
#    51,
#    73,
#    75,
#    80,
#    82,
#    83,
#    84,
#    89,
#    120,
#    126,
#    127,
#    152,
#    158,
#    186,
#    198]],
#  'effect': [9, [2, 10, 16, 49, 76, 113, 123, 166, 185]],
#  'imag': [8, [2, 35, 91, 97, 140, 169, 198, 200]],
#  'preprocess': [1, [2]],
#  'data': [10, [2, 38, 71, 85, 89, 108, 144, 157, 162, 201]],
#  'augment': [1, [2]],
#  'techniqu': [3, [2, 129, 157]],
#  'lamarckian': [1, [3]],
#  'particl': [9, [3, 17, 63, 69, 70, 93, 111, 112, 143]],
#  'swarm': [7, [3, 16, 17, 63, 70, 111, 112]],
#  'optim': [10, [3, 16, 17, 63, 64, 70, 111, 112, 130, 167]],
#  'flexibl': [3, [3, 16, 130]],
#  'ligand': [3, [3, 16, 130]],
#  'dock': [5, [3, 16, 63, 70, 130]],
#  'extract': [3, [4, 198, 200]],
#  'evolutionari': [1, [4]],
#  'backbon': [1, [4]],
#  'scientif': [2, [4, 28]],
#  'domain': [2, [4, 39]],
#  'semant': [2, [4, 144]],
#  'main': [1, [4]],
#  'path': [1, [4]],
#  'network': [25,
#   [4,
#    5,
#    24,
#    25,
#    31,
#    32,
#    34,
#    36,
#    46,
#    54,
#    62,
#    65,
#    86,
#    100,
#    113,
#    114,
#    118,
#    122,
#    142,
#    153,
#    160,
#    162,
#    169,
#    170,
#    192]],
#  'approach': [11, [4, 15, 22, 40, 46, 49, 134, 137, 138, 159, 186]],
#  'base': [13, [4, 17, 33, 69, 80, 102, 112, 116, 140, 142, 151, 158, 190]],
#  'citat': [3, [4, 28, 30]],
#  'context': [4, [4, 87, 123, 154]],
#  'analysi': [14,
#   [4, 7, 25, 26, 32, 58, 94, 105, 107, 141, 156, 166, 176, 187]],
#  'gene': [3, [5, 32, 162]],
#  'regulatori': [3, [5, 32, 162]],
#  'infer': [2, [5, 128]],
#  'link': [1, [5]],
#  'predict': [8, [5, 46, 66, 67, 89, 99, 137, 138]],
#  'graph': [2, [5, 36]],
#  'neural': [9, [5, 31, 36, 86, 100, 133, 153, 169, 173]],
#  'impos': [1, [6]],
#  'tidal': [1, [6]],
#  'wave': [1, [6]],
#  'finit': [1, [6]],
#  'element': [1, [6]],
#  'discontinu': [1, [6]],
#  'galerkin': [1, [6]],
#  'method': [9, [6, 11, 36, 44, 57, 69, 97, 105, 131]],
#  'nonlinear': [6, [7, 66, 132, 133, 173, 175]],
#  'manifold': [2, [7, 198]],
#  'eeg': [1, [7]],
#  'function': [7, [7, 23, 30, 34, 36, 103, 175]],
#  'connect': [7, [7, 23, 36, 67, 68, 103, 120]],
#  'applic': [5, [7, 114, 148, 189, 194]],
#  'alzheim': [6, [7, 23, 26, 36, 103, 107]],
#  'diseas': [7, [7, 23, 26, 36, 103, 107, 181]],
#  'born': [1, [8]],
#  'woman': [1, [8]],
#  'gender': [2, [8, 150]],
#  'robot': [1, [8]],
#  'posenormnet': [1, [9]],
#  'postur': [1, [9]],
#  'normal': [1, [9]],
#  '3d': [3, [9, 140, 200]],
#  'bodi': [1, [9]],
#  'scan': [1, [9]],
#  'arbitrari': [1, [9]],
#  'unidirect': [1, [10]],
#  'migrat': [1, [10]],
#  'popul': [3, [10, 72, 121]],
#  'alle': [1, [10]],
#  'xdll': [1, [11]],
#  'explain': [1, [11]],
#  'deep': [3, [11, 120, 186]],
#  'local': [3, [11, 69, 128]],
#  'map': [4, [11, 69, 90, 159]],
#  'vehicl': [11, [11, 15, 21, 67, 68, 101, 125, 126, 132, 136, 172]],
#  'commun': [4, [12, 116, 171, 178]],
#  'energi': [13, [12, 26, 44, 79, 94, 107, 115, 117, 142, 145, 154, 167, 189]],
#  'manag': [3, [12, 96, 148]],
#  'system': [19,
#   [12,
#    22,
#    47,
#    76,
#    85,
#    88,
#    96,
#    101,
#    102,
#    115,
#    116,
#    119,
#    124,
#    126,
#    133,
#    135,
#    154,
#    173,
#    193]],
#  'smart': [5, [12, 68, 120, 144, 165]],
#  'microgrid': [2, [12, 71]],
#  'hybrid': [4, [13, 91, 92, 160]],
#  'linear': [3, [13, 52, 75]],
#  'iter': [1, [13]],
#  'cluster': [3, [13, 77, 156]],
#  'bay': [1, [13]],
#  'grabcut': [1, [13]],
#  'segment': [5, [13, 91, 97, 169, 199]],
#  'scheme': [2, [13, 119]],
#  'dynam': [6, [13, 22, 32, 40, 72, 132]],
#  'cervic': [1, [13]],
#  'cancer': [2, [13, 122]],
#  'alloc': [1, [14]],
#  'medic': [2, [14, 89]],
#  'resourc': [1, [14]],
#  'vaccin': [3, [14, 29, 37]],
#  'control': [4, [14, 46, 71, 112]],
#  'pandem': [1, [14]],
#  'optimis': [6, [15, 85, 96, 135, 141, 190]],
#  'rout': [1, [15]],
#  'problem': [3, [15, 17, 39]],
#  'uniqu': [1, [15]],
#  'locat': [1, [15]],
#  'depot': [1, [15]],
#  'intellig': [2, [16, 21]],
#  'algorithm': [9, [16, 17, 29, 33, 39, 112, 152, 158, 167]],
#  'improv': [9, [17, 72, 85, 94, 98, 121, 122, 135, 142]],
#  'gaussian': [5, [17, 45, 60, 75, 141]],
#  'distribut': [9, [17, 46, 52, 60, 71, 88, 102, 116, 194]],
#  'engin': [1, [17]],
#  'shape': [1, [17]],
#  'design': [2, [17, 71]],
#  'integr': [2, [18, 43]],
#  'framework': [8, [18, 43, 46, 91, 92, 99, 138, 144]],
#  'diagnos': [2, [18, 119]],
#  'process': [6, [18, 45, 60, 75, 141, 175]],
#  'fault': [6, [18, 93, 119, 132, 134, 143]],
#  'incomplet': [2, [18, 89]],
#  'featur': [2, [18, 185]],
#  'smt': [3, [19, 20, 139]],
#  'solver': [2, [19, 20]],
#  'real': [4, [19, 20, 110, 139]],
#  'arithmet': [4, [19, 20, 110, 139]],
#  'insid': [2, [19, 20]],
#  'mapl': [2, [19, 20]],
#  'artifici': [1, [21]],
#  'car': [1, [21]],
#  'close': [1, [21]],
#  'yet': [1, [21]],
#  'far': [1, [21]],
#  'fulli': [1, [21]],
#  'autonom': [3, [21, 67, 136]],
#  'risk': [1, [22]],
#  'dairi': [1, [22]],
#  'suppli': [1, [22]],
#  'chain': [2, [22, 52]],
#  'classif': [7, [23, 24, 30, 36, 49, 80, 122]],
#  'brain': [2, [24, 91]],
#  'tumor': [1, [24]],
#  'combin': [2, [24, 116]],
#  'variat': [1, [24]],
#  'autoencod': [1, [24]],
#  'gener': [11, [24, 43, 52, 57, 108, 118, 119, 122, 131, 166, 170]],
#  'adversari': [6, [24, 89, 118, 119, 122, 170]],
#  'cell': [5, [25, 48, 105, 176, 187]],
#  'site': [4, [25, 105, 176, 187]],
#  'landscap': [2, [26, 107]],
#  'clog': [1, [27]],
#  'shawl': [1, [27]],
#  'mormon': [3, [27, 150, 178]],
#  'moorland': [1, [27]],
#  'search': [2, [27, 110]],
#  'zion': [1, [27]],
#  'compar': [3, [28, 29, 32]],
#  'summar': [1, [28]],
#  'paper': [1, [28]],
#  'guid': [2, [28, 111]],
#  'behaviour': [4, [29, 59, 161, 185]],
#  'two': [3, [29, 123, 145]],
#  'tweet': [1, [29]],
#  'contextualis': [1, [30]],
#  'convolut': [1, [31]],
#  'pothol': [1, [31]],
#  'critic': [1, [31]],
#  'road': [1, [31]],
#  'infrastructur': [1, [31]],
#  'sleep': [2, [33, 183]],
#  'apnea': [1, [33]],
#  'machin': [12, [33, 51, 66, 73, 75, 82, 83, 84, 152, 156, 158, 177]],
#  'ecg': [1, [33]],
#  'signal': [3, [33, 133, 173]],
#  'comprehens': [1, [33]],
#  'systemat': [6, [33, 81, 179, 181, 183, 184]],
#  'review': [10, [33, 39, 44, 81, 101, 136, 179, 181, 183, 184]],
#  'differenti': [3, [34, 55, 75]],
#  'radial': [1, [34]],
#  'basi': [1, [34]],
#  'sequenc': [2, [34, 121]],
#  'densenet': [1, [35]],
#  'fluoroscopi': [3, [35, 140, 198]],
#  'denois': [1, [35]],
#  'cardiac': [3, [35, 198, 200]],
#  'electrophysiolog': [1, [35]],
#  'procedur': [1, [35]],
#  'empir': [2, [36, 95]],
#  'evalu': [5, [36, 113, 116, 168, 190]],
#  'efficaci': [1, [37]],
#  'race': [1, [37]],
#  'ethnic': [2, [37, 78]],
#  'examin': [1, [38]],
#  'type': [3, [38, 40, 194]],
#  '1': [3, [38, 40, 108]],
#  'experiment': [1, [38]],
#  'exploit': [1, [39]],
#  'structur': [2, [39, 170]],
#  'heurist': [2, [39, 58]],
#  'set': [2, [39, 65]],
#  'cover': [3, [39, 61, 110]],
#  'literatur': [1, [39]],
#  'explor': [1, [40]],
#  'properti': [2, [40, 194]],
#  'sensit': [3, [40, 128, 141]],
#  'fast': [1, [41]],
#  'detail': [1, [41]],
#  'accur': [2, [41, 157]],
#  'simul': [2, [41, 55]],
#  'thermal': [4, [41, 168, 180, 191]],
#  'feedback': [1, [42]],
#  'engag': [1, [42]],
#  'introductori': [1, [42]],
#  'program': [1, [42]],
#  'modul': [1, [42]],
#  'express': [1, [43]],
#  'theori': [2, [44, 61]],
#  'practic': [2, [44, 79]],
#  'humanitarian': [2, [44, 117]],
#  'ecosystem': [1, [44]],
#  'emul': [1, [45]],
#  'output': [1, [45]],
#  '2d': [2, [45, 200]],
#  'inland': [1, [45]],
#  'flood': [2, [45, 113]],
#  'incorpor': [1, [46]],
#  'forecast': [1, [46]],
#  'negoti': [2, [46, 155]],
#  'mesh': [1, [46]],
#  'electr': [1, [46]],
#  'formula': [1, [47]],
#  'number': [1, [47]],
#  'solut': [2, [47, 117]],
#  'parametr': [1, [47]],
#  'polynomi': [3, [47, 65, 158]],
#  'equat': [2, [47, 55]],
#  'levelwis': [1, [48]],
#  'construct': [2, [48, 162]],
#  'singl': [1, [48]],
#  'cylindr': [6, [48, 58, 61, 77, 110, 146]],
#  'algebra': [10, [48, 51, 58, 61, 72, 77, 110, 121, 146, 192]],
#  'leverag': [1, [49]],
#  'arab': [1, [49]],
#  'sentiment': [1, [49]],
#  'enhanc': [3, [49, 68, 199]],
#  'text': [1, [49]],
#  'prepar': [1, [49]],
#  'lift': [1, [50]],
#  'lncrna': [1, [50]],
#  'identif': [3, [50, 133, 173]],
#  'tool': [5, [50, 72, 121, 152, 192]],
#  'comput': [8, [51, 75, 129, 149, 156, 167, 177, 197]],
#  'markov': [1, [52]],
#  'mont': [2, [52, 55]],
#  'estim': [5, [52, 93, 132, 143, 186]],
#  'reliabl': [2, [52, 105]],
#  'paramet': [1, [52]],
#  'failur': [1, [52]],
#  'rate': [2, [52, 186]],
#  'matrix': [1, [53]],
#  'decomposit': [5, [53, 58, 77, 112, 146]],
#  'transform': [1, [53]],
#  'unit': [3, [53, 100, 163]],
#  'sphere': [1, [53]],
#  'ellipsoid': [1, [53]],
#  'dilat': [1, [53]],
#  'rotat': [1, [53]],
#  'shear': [1, [53]],
#  'minim': [1, [54]],
#  'age': [2, [54, 180]],
#  'inform': [3, [54, 55, 198]],
#  'wireless': [1, [54]],
#  'sensor': [7, [54, 76, 93, 100, 106, 132, 143]],
#  'carlo': [1, [55]],
#  'stochast': [1, [55]],
#  'studi': [9, [55, 72, 95, 102, 103, 121, 164, 180, 192]],
#  'geometri': [1, [55]],
#  'faith': [1, [56]],
#  'children': [4, [56, 78, 147, 193]],
#  'care': [5, [56, 78, 147, 184, 193]],
#  'strateg': [1, [56]],
#  'brief': [2, [56, 108]],
#  'lock': [2, [57, 131]],
#  'valu': [3, [57, 108, 131]],
#  'determin': [2, [57, 131]],
#  'instantan': [2, [57, 131]],
#  'phase': [2, [57, 131]],
#  'coupl': [2, [57, 131]],
#  'new': [5, [58, 96, 97, 128, 159]],
#  'choos': [1, [58]],
#  'variabl': [2, [58, 158]],
#  'order': [2, [58, 158]],
#  'motiv': [1, [58]],
#  'complex': [2, [58, 156]],
#  'boil': [1, [59]],
#  'monitor': [1, [59]],
#  'cook': [1, [59]],
#  'refuge': [3, [59, 145, 189]],
#  'settlement': [2, [59, 94]],
#  'prior': [1, [60]],
#  'effici': [2, [60, 114]],
#  'spars': [1, [60]],
#  'regress': [1, [60]],
#  'implement': [2, [61, 90]],
#  'satisfi': [1, [61]],
#  'modulo': [1, [61]],
#  'solv': [1, [61]],
#  'scalabl': [2, [62, 160]],
#  'lora': [1, [62]],
#  'imperfect': [1, [62]],
#  'sf': [1, [62]],
#  'orthogon': [1, [62]],
#  'parallel': [1, [63]],
#  'cooper': [1, [63]],
#  'virtual': [2, [63, 130]],
#  'screen': [2, [63, 130]],
#  'part': [1, [64]],
#  'speech': [1, [64]],
#  'tag': [1, [64]],
#  'investig': [3, [64, 108, 123]],
#  'runtim': [1, [64]],
#  'quantum': [2, [64, 156]],
#  'formul': [1, [64]],
#  'zx': [1, [64]],
#  'calculu': [1, [64]],
#  'superlevel': [1, [65]],
#  'represent': [4, [65, 66, 87, 120]],
#  'multistationar': [2, [65, 192]],
#  'region': [2, [65, 164]],
#  'chemic': [2, [65, 192]],
#  'reaction': [2, [65, 192]],
#  'primari': [1, [66]],
#  'interact': [1, [66]],
#  'mercer': [1, [66]],
#  'seri': [2, [66, 102]],
#  'support': [5, [66, 129, 137, 156, 177]],
#  'vector': [3, [66, 156, 177]],
#  'public': [1, [67]],
#  'adopt': [2, [67, 197]],
#  'privaci': [2, [68, 109]],
#  'technolog': [3, [68, 165, 189]],
#  'pet': [1, [68]],
#  'citi': [3, [68, 144, 165]],
#  'rapid': [1, [69]],
#  'adapt': [1, [69]],
#  'filter': [3, [69, 93, 143]],
#  'rdpsovina': [1, [70]],
#  'random': [3, [70, 111, 156]],
#  'drift': [2, [70, 111]],
#  'resili': [1, [71]],
#  'consensu': [1, [71]],
#  'dc': [1, [71]],
#  'fals': [1, [71]],
#  'inject': [1, [71]],
#  'attack': [1, [71]],
#  'bank': [1, [71]],
#  'slide': [1, [71]],
#  'mode': [1, [71]],
#  'observ': [1, [71]],
#  'save': [1, [72]],
#  'research': [3, [72, 154, 168]],
#  'budget': [1, [72]],
#  'futur': [3, [73, 79, 161]],
#  'progress': [1, [73]],
#  'overview': [1, [74]],
#  '2021': [1, [74]],
#  'stabl': [1, [75]],
#  'likelihood': [1, [75]],
#  'oper': [3, [75, 96, 201]],
#  'switch': [2, [76, 116]],
#  'tracker': [1, [76]],
#  'fusion': [2, [76, 100]],
#  'advanc': [1, [76]],
#  'driver': [1, [76]],
#  'assist': [2, [76, 106]],
#  'benefit': [1, [77]],
#  'polit': [1, [78]],
#  'match': [1, [78]],
#  'religion': [1, [78]],
#  'uk': [1, [78]],
#  'ai': [1, [79]],
#  'ethic': [1, [79]],
#  'transit': [1, [79]],
#  'kaggl': [1, [80]],
#  'eyepac': [1, [80]],
#  'dataset': [4, [80, 125, 172, 191]],
#  'trustworthi': [1, [81]],
#  'autom': [3, [81, 126, 141]],
#  'interview': [1, [81]],
#  'coventri': [1, [81]],
#  'univers': [3, [81, 180, 197]],
#  'anomali': [2, [82, 83]],
#  'gamma': [2, [82, 83]],
#  'radiat': [2, [82, 83]],
#  'sc2': [1, [84]],
#  'adm1': [1, [85]],
#  'measur': [2, [85, 128]],
#  'perform': [3, [85, 135, 190]],
#  'exist': [2, [85, 135]],
#  'anaerob': [2, [85, 135]],
#  'digest': [2, [85, 135]],
#  'word': [1, [87]],
#  'refin': [1, [87]],
#  'access': [2, [88, 94]],
#  'point': [1, [88]],
#  'select': [2, [88, 185]],
#  'strategi': [2, [88, 160]],
#  'indoor': [3, [88, 102, 171]],
#  '5g': [1, [88]],
#  'antenna': [3, [88, 102, 116]],
#  'imbalanc': [1, [89]],
#  'robust': [1, [89]],
#  'surviv': [1, [89]],
#  'liver': [1, [89]],
#  'transplant': [1, [89]],
#  'patient': [4, [89, 179, 183, 184]],
#  'hardwar': [2, [90, 159]],
#  'tissu': [1, [91]],
#  'magnet': [1, [91]],
#  'reson': [1, [91]],
#  'elimin': [1, [92]],
#  'power': [3, [92, 102, 119]],
#  'grid': [1, [92]],
#  'regular': [2, [93, 143]],
#  'ambigu': [1, [93]],
#  'standalon': [1, [94]],
#  'solar': [2, [94, 145]],
#  'streetlight': [1, [94]],
#  'displac': [2, [94, 154]],
#  'span': [1, [95]],
#  'scienc': [2, [95, 108]],
#  'ner': [1, [95]],
#  'fuzzi': [2, [96, 98]],
#  'contain': [2, [96, 98]],
#  'yard': [2, [96, 98]],
#  'satellit': [2, [97, 169]],
#  'long': [1, [98]],
#  'stay': [1, [98]],
#  'probabilist': [3, [99, 138, 164]],
#  'econom': [2, [99, 113]],
#  'reusabl': [3, [99, 138, 144]],
#  'build': [4, [99, 104, 138, 180]],
#  'compon': [2, [99, 138]],
#  'develop': [3, [99, 138, 152]],
#  'circular': [2, [99, 138]],
#  'economi': [2, [99, 138]],
#  'quaternion': [1, [100]],
#  'gate': [1, [100]],
#  'recurr': [1, [100]],
#  'collis': [1, [101]],
#  'avoid': [1, [101]],
#  'unman': [2, [101, 132]],
#  'aerial': [2, [101, 132]],
#  'correl': [1, [102]],
#  'channel': [2, [102, 166]],
#  'imbal': [1, [102]],
#  'divers': [3, [102, 111, 112]],
#  'gain': [1, [102]],
#  '60': [1, [102]],
#  'ghz': [1, [102]],
#  'capac': [2, [104, 166]],
#  'heed': [1, [104]],
#  'skill': [1, [104]],
#  'audit': [1, [104]],
#  'recommend': [2, [104, 154]],
#  'survey': [3, [105, 129, 171]],
#  'centralis': [1, [106]],
#  'decentralis': [1, [106]],
#  'emerg': [1, [106]],
#  'brake': [1, [106]],
#  'polici': [1, [108]],
#  'citizen': [1, [108]],
#  'add': [1, [108]],
#  'complianc': [1, [108]],
#  'protect': [1, [108]],
#  'regul': [1, [108]],
#  'gdpr': [1, [108]],
#  'right': [1, [109]],
#  'onlin': [1, [109]],
#  'decid': [1, [110]],
#  'consist': [1, [110]],
#  'constraint': [1, [110]],
#  'conflict': [1, [110]],
#  'driven': [1, [110]],
#  'collabor': [1, [111]],
#  'mental': [1, [113]],
#  'health': [2, [113, 120]],
#  'bayesian': [3, [113, 128, 162]],
#  'activ': [2, [114, 151]],
#  'recognit': [2, [114, 151]],
#  'lightweight': [1, [114]],
#  'cnn': [1, [114]],
#  'surveil': [1, [114]],
#  'ensur': [1, [115]],
#  'accuraci': [1, [115]],
#  'awar': [1, [115]],
#  'schedul': [1, [115]],
#  'heterogen': [1, [115]],
#  'da': [1, [116]],
#  'find': [1, [117]],
#  'uncomfort': [1, [117]],
#  'respons': [1, [117]],
#  'innov': [1, [117]],
#  'pedestrian': [3, [118, 136, 170]],
#  'cross': [1, [118]],
#  'scenario': [2, [118, 141]],
#  'guest': [1, [120]],
#  'editori': [1, [120]],
#  'special': [1, [120]],
#  'issu': [2, [120, 163]],
#  'bifurc': [1, [121]],
#  'skin': [1, [122]],
#  'student': [1, [122]],
#  'fragranc': [1, [123]],
#  'comfort': [1, [123]],
#  'automot': [1, [123]],
#  'seamless': [1, [124]],
#  'highway': [1, [124]],
#  'inerti': [3, [125, 126, 172]],
#  'odometri': [4, [125, 127, 153, 172]],
#  'benchmark': [2, [125, 172]],
#  'ground': [2, [125, 172]],
#  'posit': [2, [125, 172]],
#  'localis': [4, [126, 127, 153, 186]],
#  'navig': [1, [126]],
#  'in': [1, [126]],
#  'uncertainti': [1, [127]],
#  'wheel': [2, [127, 153]],
#  'vehicular': [3, [127, 153, 186]],
#  'gnss': [2, [127, 186]],
#  'depriv': [1, [127]],
#  'class': [1, [128]],
#  'metric': [1, [128]],
#  'mobil': [1, [129]],
#  'disast': [1, [129]],
#  'evacu': [1, [129]],
#  'guidanc': [1, [129]],
#  'msldock': [1, [130]],
#  'unknown': [1, [132]],
#  'fix': [1, [132]],
#  'wing': [1, [132]],
#  'neurophysiolog': [2, [133, 173]],
#  'novel': [1, [134]],
#  'mitig': [1, [134]],
#  'soc': [1, [134]],
#  'recoveri': [1, [134]],
#  'feedstock': [1, [135]],
#  'flowrat': [1, [135]],
#  'percept': [3, [136, 180, 191]],
#  'mortal': [1, [137]],
#  'durat': [2, [137, 164]],
#  'treatment': [1, [137]],
#  'pulmonari': [1, [137]],
#  'embol': [1, [137]],
#  'requir': [1, [137]],
#  'ceil': [1, [137]],
#  'ventilatori': [1, [137]],
#  'inpati': [2, [137, 152]],
#  'technic': [1, [138]],
#  'toward': [3, [138, 149, 154]],
#  'prove': [1, [139]],
#  'unsat': [1, [139]],
#  'case': [3, [139, 164, 180]],
#  'quantifi': [1, [139]],
#  'free': [2, [139, 190]],
#  'registr': [1, [140]],
#  'echo': [1, [140]],
#  'cascad': [1, [140]],
#  'classifi': [1, [140]],
#  'safe': [1, [141]],
#  'drive': [1, [141]],
#  'secur': [1, [142]],
#  'harvest': [1, [142]],
#  'overlay': [1, [142]],
#  'cognit': [1, [142]],
#  'destin': [1, [142]],
#  'simultan': [1, [143]],
#  'actuat': [1, [143]],
#  'aircraft': [1, [143]],
#  'ssf': [1, [144]],
#  'intervent': [2, [145, 200]],
#  'lesson': [1, [145]],
#  'rwandan': [1, [145]],
#  'camp': [2, [145, 189]],
#  'dewcad': [1, [146]],
#  'project': [2, [146, 191]],
#  'push': [1, [146]],
#  'back': [1, [146]],
#  'doubli': [1, [146]],
#  'exponenti': [2, [146, 194]],
#  'wall': [1, [146]],
#  'salienc': [1, [147]],
#  'islam': [1, [147]],
#  'muslim': [2, [147, 193]],
#  'heritag': [1, [147]],
#  'experi': [1, [147]],
#  'ident': [1, [147]],
#  'famili': [2, [147, 155]],
#  'foster': [1, [147]],
#  'topic': [1, [148]],
#  'precis': [1, [148]],
#  'medicin': [1, [148]],
#  'person': [1, [148]],
#  'physic': [2, [149, 179]],
#  'equilibrium': [1, [149]],
#  'unpack': [1, [150]],
#  'sexual': [1, [150]],
#  'contemporari': [2, [150, 163]],
#  'unsupervis': [1, [151]],
#  'doppler': [1, [151]],
#  'radar': [1, [151]],
#  'clinic': [1, [152]],
#  'whonet': [1, [153]],
#  'work': [1, [154]],
#  'modern': [1, [154]],
#  'afford': [1, [154]],
#  'sustain': [1, [154]],
#  'practition': [1, [154]],
#  'come': [1, [155]],
#  'follow': [1, [155]],
#  'sacralis': [1, [155]],
#  'home': [1, [155]],
#  'guardian': [1, [155]],
#  'european': [1, [155]],
#  'women': [1, [155]],
#  'domest': [1, [155]],
#  'space': [1, [155]],
#  'church': [2, [155, 163]],
#  'jesu': [2, [155, 163]],
#  'christ': [2, [155, 163]],
#  'saint': [2, [155, 163]],
#  'leap': [1, [156]],
#  'low': [2, [157, 186]],
#  'cost': [1, [157]],
#  'highli': [1, [157]],
#  'big': [1, [157]],
#  'interpol': [1, [157]],
#  'softwar': [1, [158]],
#  'pipelin': [1, [158]],
#  'pick': [1, [158]],
#  'input': [1, [158]],
#  'mac': [1, [160]],
#  'analyt': [1, [161]],
#  'prevent': [1, [161]],
#  'mean': [1, [161]],
#  'polic': [1, [161]],
#  'microarray': [1, [162]],
#  'ireland': [1, [163]],
#  'kingdom': [1, [163]],
#  'intens': [1, [164]],
#  'cold': [1, [164]],
#  'episod': [1, [164]],
#  'malay': [1, [164]],
#  'vineyard': [1, [164]],
#  'digit': [1, [165]],
#  'twin': [1, [165]],
#  'composit': [1, [166]],
#  'fade': [2, [166, 174]],
#  'joint': [1, [167]],
#  'task': [1, [167]],
#  'genet': [1, [167]],
#  'assumpt': [1, [168]],
#  'scale': [2, [168, 191]],
#  'subject': [1, [168]],
#  'layperson': [1, [168]],
#  'perceiv': [1, [168]],
#  'way': [1, [168]],
#  'believ': [1, [168]],
#  'farm': [1, [169]],
#  'area': [1, [169]],
#  'pose': [1, [170]],
#  'visibl': [1, [171]],
#  'tutori': [1, [171]],
#  'shadow': [1, [174]],
#  'central': [1, [175]],
#  'limit': [1, [175]],
#  'theorem': [2, [175, 190]],
#  'first': [1, [175]],
#  'passag': [1, [175]],
#  'reward': [1, [175]],
#  'opinion': [1, [176]],
#  'evid': [1, [176]],
#  'consider': [1, [177]],
#  'empti': [1, [178]],
#  'womb': [1, [178]],
#  'unansw': [1, [178]],
#  'prayer': [1, [178]],
#  'femal': [1, [178]],
#  'infertil': [1, [178]],
#  'involuntari': [1, [178]],
#  'childless': [1, [178]],
#  'british': [1, [178]],
#  'exercis': [1, [179]],
#  'fatigu': [1, [179]],
#  'symptom': [1, [179]],
#  'multipl': [1, [179]],
#  'sclerosi': [1, [179]],
#  'influenc': [1, [180]],
#  'acclimat': [1, [180]],
#  'scotland': [1, [180]],
#  'england': [2, [180, 193]],
#  'preval': [4, [181, 182, 183, 184]],
#  'restless': [1, [181]],
#  'leg': [1, [181]],
#  'third': [1, [181]],
#  'trimest': [1, [181]],
#  'pregnanc': [1, [181]],
#  'sever': [1, [182]],
#  'depress': [2, [182, 184]],
#  'iranian': [1, [182]],
#  'older': [1, [182]],
#  'adult': [1, [182]],
#  'disturb': [1, [183]],
#  'among': [2, [183, 193]],
#  'physician': [1, [183]],
#  'nurs': [1, [183]],
#  'face': [1, [183]],
#  'stress': [1, [184]],
#  'anxieti': [1, [184]],
#  'within': [1, [184]],
#  'healthcar': [1, [184]],
#  'worker': [1, [184]],
#  'understand': [2, [185, 193]],
#  'household': [1, [185]],
#  'fuel': [1, [185]],
#  'choic': [1, [185]],
#  'amazona': [1, [185]],
#  'state': [1, [185]],
#  'brazil': [1, [185]],
#  'valid': [1, [185]],
#  'high': [1, [186]],
#  'outag': [1, [186]],
#  'role': [1, [187]],
#  'interpret': [2, [187, 191]],
#  'mass': [1, [188]],
#  'transpir': [1, [188]],
#  'boundari': [1, [188]],
#  'layer': [1, [188]],
#  'flow': [1, [188]],
#  'superlinear': [1, [188]],
#  'stretch': [1, [188]],
#  'sheet': [1, [188]],
#  'embed': [1, [188]],
#  'porou': [1, [188]],
#  'medium': [1, [188]],
#  'slip': [1, [188]],
#  'remot': [1, [189]],
#  'sens': [1, [189]],
#  'spontan': [1, [190]],
#  'fruit': [1, [190]],
#  'fli': [1, [190]],
#  'truss': [1, [190]],
#  'weight': [2, [190, 194]],
#  'minimis': [1, [190]],
#  'lunch': [1, [190]],
#  'last': [1, [193]],
#  'one': [1, [193]],
#  'leav': [1, [193]],
#  'journey': [1, [193]],
#  'discret': [1, [194]],
#  'second': [1, [194]],
#  'h': [1, [195]],
#  'pt': [1, [195]],
#  '一种鼓励质量平衡产量的': [1, [195]],
#  '型指数': [1, [195]],
#  '基于城市群的空气质量数据的可视分析方法研究': [1, [196]],
#  'major': [1, [197]],
#  'cloud': [1, [197]],
#  'europ': [1, [197]],
#  'vs': [1, [197]],
#  'middl': [1, [197]],
#  'east': [1, [197]],
#  'respiratori': [1, [198]],
#  'motion': [1, [198]],
#  'hierarch': [1, [198]],
#  'infarct': [1, [199]],
#  'delay': [1, [199]],
#  'mri': [1, [199]],
#  'left': [1, [199]],
#  'ventricl': [1, [199]],
#  'cathet': [1, [200]],
#  'fluoroscop': [1, [200]],
#  'echocardiograph': [1, [200]],
#  'ad': [1, [201]],
#  'logic': [1, [201]],
#  'tree': [1, [201]],
#  'pattern': [1, [201]],
#  'queri': [1, [201]]}

# %% [markdown]
# ### **Example of implementation**

# %%
# example of the implementation of indexer- limited to just max of 2 termed query

flatten_list = [item for items in cleaned_titles for item in items]

query = 'gaussian distribution'
token_query = word_tokenize(query)
token_lower = [w.lower() for w in token_query if w.isalnum()]
stopped_query = [w for w in token_lower if w not in stopwords.words('english')]
stemmed = [ps.stem(w) for w in stopped_query]
print(stemmed)

if len(stemmed) == 1 and (stemmed[-1] in flatten_list):
    infor = inverted_index[stemmed[-1]]
    post_list = infor[1]
    print(f'{stemmed[-1]} present in these docid :{post_list}')

elif len(stemmed) == 2:
    result =  []
    for word in stemmed:
        if word in flatten_list:
            infor = inverted_index[word]
            lists = infor[1]
            print(f'{word} is present in these docid: {lists}')
            result.append(lists)

        else:
            print(f'{word} is not present in any publication')
            post_list = lists
            print(post_list)

    if len(result) > 1:
        post_list = list(set.intersection(*map(set,result)))
        print(f'both words are present in {post_list}')
# Out:
# ['gaussian', 'distribut']
# gaussian is present in these docid: [17, 45, 60, 75, 141]
# distribut is present in these docid: [17, 46, 52, 60, 71, 88, 102, 116, 194]
# both words are present in [17, 60]

# %% [markdown]
# ## **Implementation of Query Processor**

# %%
docid = []
for i in range(1, (len(data)+1)):
    docid.append(i)

# dictionary of data with docid as key and main data as nested dictionary
#- this will be the processor result
data_dict = dict(zip(docid, data))

# convert data to a data frame with docid as index to help visualise each data better
df = pd.DataFrame(data)
df['doc_id'] = docid
df = df.set_index('doc_id')

data_dict
# Out:
# {1: {'Publication title': 'an extended plant circadian clock model for characterising flowering time under different light quality conditions',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-extended-plant-circadian-clock-model-for-characterising-flower',
#   'Abstract': 'Speed breeding has recently emerged as an innovative agricultural technology solution to meet the ever-increasing global food demand...',
#   'Date': '9 Jan 2023',
#   'Author information': ['Miao Lin Pay, https://pureportal.coventry.ac.uk/en/persons/miao-lin-pay',
#    'Jesper Christensen, https://pureportal.coventry.ac.uk/en/persons/jesper-christensen',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he',
#    'Laura Roden, https://pureportal.coventry.ac.uk/en/persons/laura-roden']},
#  2: {'Publication title': 'challenges and prospects of climate change impact assessment on mangrove environments through mathematical models',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/challenges-and-prospects-of-climate-change-impact-assessment-on-m',
#   'Abstract': 'The impacts of climate change, especially sea-level rise, are an increasing threat to the world’s coastal regions...',
#   'Date': '25 Feb 2023',
#   'Author information': ['Majdi Fanous, https://pureportal.coventry.ac.uk/en/persons/majdi-fanous',
#    'Jonathan Eden, https://pureportal.coventry.ac.uk/en/persons/jonathan-eden',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  3: {'Publication title': 'diabetic retinopathy detection using transfer and reinforcement learning with effective image preprocessing and data augmentation techniques',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/diabetic-retinopathy-detection-using-transfer-and-reinforcement-l',
#   'Abstract': 'Diabetic retinopathy is the consequence of advanced stages of diabetes, which can ultimately lead to permanent blindness...',
#   'Date': '7 Feb 2023',
#   'Author information': ['Maria Tariq, https://pureportal.coventry.ac.uk/en/persons/maria-tariq',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade',
#    'YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  4: {'Publication title': 'entropy‐based lamarckian quantum‐behaved particle swarm optimization for flexible ligand docking',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/entropybased-lamarckian-quantumbehaved-particle-swarm-optimizatio',
#   'Abstract': 'AutoDock is a widely used software for flexible ligand docking problems since it is open source and easy to be implemented...',
#   'Date': '31 Jan 2023',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  5: {'Publication title': 'extracting the evolutionary backbone of scientific domains: the semantic main path network approach based on citation context analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/extracting-the-evolutionary-backbone-of-scientific-domains-the-se',
#   'Abstract': 'Main path analysis is a popular method for extracting the scientific backbone from the citation network of a research domain...',
#   'Date': '15 Feb 2023',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  6: {'Publication title': 'gene regulatory network inference through link prediction using graph neural network',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/gene-regulatory-network-inference-through-link-prediction-using-g',
#   'Abstract': 'Gene Regulatory Networks (GRNs) depict the causal regulatory interactions between transcription factors (TFs) and their target genes [2], where TFs are proteins that regulate gene transcription...',
#   'Date': '19 Jan 2023',
#   'Author information': ['Sivasharmini Ganeshamoorthy, https://pureportal.coventry.ac.uk/en/persons/sivasharmini-ganeshamoorthy',
#    'Laura Roden, https://pureportal.coventry.ac.uk/en/persons/laura-roden',
#    'Dominik Klepl, https://pureportal.coventry.ac.uk/en/persons/dominik-klepl',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  7: {'Publication title': 'hydro-morphodynamic modelling of mangroves imposed by tidal waves using finite element discontinuous galerkin method',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/hydro-morphodynamic-modelling-of-mangroves-imposed-by-tidal-waves',
#   'Abstract': 'Modelling the hydro-morphodynamics of mangrove environments is key for implementing successful protection and restoration projects in a climatically vulnerable region...',
#   'Date': '21 Mar 2023',
#   'Author information': ['Majdi Fanous, https://pureportal.coventry.ac.uk/en/persons/majdi-fanous',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah',
#    'Jonathan M. Eden, https://pureportal.coventry.ac.uk/en/persons/jonathan-eden',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  8: {'Publication title': "kernel-based nonlinear manifold learning for eeg functional connectivity analysis with application to alzheimer's disease",
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/kernel-based-nonlinear-manifold-learning-for-eeg-functional-conne',
#   'Abstract': 'Dynamical, causal and cross-frequency coupling analysis using the EEG has received significant interest for the analysis and diagnosis of neurological disorders [1]–[3]...',
#   'Date': '19 Jan 2023',
#   'Author information': ['Shenal Rajintha Alexander Samarathunge Gunawardena, https://pureportal.coventry.ac.uk/en/persons/shenal-rajintha-alexander-samarathunge-gunawardena',
#    'F. He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  9: {'Publication title': 'not born of woman: gendered robots',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/not-born-of-woman-gendered-robots',
#   'Abstract': "This chapter posits that gender, while being messy and non-binary, is a salient consideration in the development of virtual and embodied robots to avoid replicating stereotypical representations of men and women's roles and occupations in our future artificial work colleagues, and companions...",
#   'Date': '26 Feb 2023',
#   'Author information': ['Huma Shah, https://pureportal.coventry.ac.uk/en/persons/huma-shah']},
#  10: {'Publication title': 'posenormnet: identity-preserved posture normalization of 3d body scans in arbitrary postures',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/posenormnet-identity-preserved-posture-normalization-of-3d-body-s',
#   'Abstract': '3D human models accurately represent the shape of the subjects, which is key to many human-centric industrial applications, including fashion design, body biometrics extraction, and computer animation...',
#   'Date': '16 Feb 2023',
#   'Author information': ['Pengpeng Hu, https://pureportal.coventry.ac.uk/en/persons/pengpeng-hu']},
#  11: {'Publication title': 'unidirectional migration of populations with allee effect',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/unidirectional-migration-of-populations-with-allee-effect',
#   'Abstract': 'In this note we consider two populations living on identical patches, connected by unidirectional migration, and subject to strong Allee effect...',
#   'Date': '10 Jan 2023',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh',
#    'AmirHosein Sadeghimanesh Sadeghi Manesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  12: {'Publication title': 'xdll: explained deep learning lidar-based localization and mapping method for self-driving vehicles',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/xdll-explained-deep-learning-lidar-based-localization-and-mapping',
#   'Abstract': 'Self-driving vehicles need a robust positioning system to continue the revolution in intelligent transportation...',
#   'Date': '22 Jan 2023',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  13: {'Publication title': 'a community energy management system for smart microgrids',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/a-community-energy-management-system-for-smart-microgrids',
#   'Abstract': 'Community micro-grid energy projects are needed to drive de-carbonisation and increase equity of energy systems among displaced communities...',
#   'Date': '9 Apr 2022',
#   'Author information': ['Jonathan Daniel Nixon, https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford']},
#  14: {'Publication title': 'a hybrid linear iterative clustering and bayes classification-based grabcut segmentation scheme for dynamic detection of cervical cancer',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/a-hybrid-linear-iterative-clustering-and-bayes-classification-bas',
#   'Abstract': 'Cervical cancer earlier detection remains indispensable for enhancing the survival rate probability among women patients worldwide...',
#   'Date': '18 Oct 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  15: {'Publication title': 'allocating medical resources (vaccine) to control a pandemic',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/allocating-medical-resources-vaccine-to-control-a-pandemic',
#   'Abstract': 'In the aftermath of the COVID-19 pandemic, we need to better understand how to prepare for other pandemics in the future...',
#   'Date': '26 Apr 2022',
#   'Author information': ['Michael Ajao-Olarinoye, https://pureportal.coventry.ac.uk/en/persons/michael-ajao-olarinoye']},
#  16: {'Publication title': 'an agent-based optimisation approach for vehicle routing problem with unique vehicle location and depot',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-agent-based-optimisation-approach-for-vehicle-routing-problem-',
#   'Abstract': 'The Vehicle Routing Problem (VRP) is a well studied logistical problem along with its various variants such as VRP with customer Time-Window (VRPTW)...',
#   'Date': '20 Dec 2021',
#   'Author information': ['Ammar Al Bazi, https://pureportal.coventry.ac.uk/en/persons/ammar-al-bazi',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  17: {'Publication title': 'an effective swarm intelligence optimization algorithm for flexible ligand docking',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-effective-swarm-intelligence-optimization-algorithm-for-flexib',
#   'Abstract': 'In general, flexible ligand docking is used for docking simulations under the premise that the position of the binding site is already known, and meanwhile, it can also be used without prior knowledge of the binding site...',
#   'Date': '10 Aug 2021',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  18: {'Publication title': 'an improved gaussian distribution based quantum-behaved particle swarm optimization algorithm for engineering shape design problems',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-improved-gaussian-distribution-based-quantum-behaved-particle-',
#   'Abstract': 'In this article, an improved Gaussian distribution based quantum-behaved particle swarm optimization (IG-QPSO) algorithm is proposed to solve engineering shape design problems with multiple constraints...',
#   'Date': '23 Mar 2021',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  19: {'Publication title': 'an integrated framework for diagnosing process faults with incomplete features',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-integrated-framework-for-diagnosing-process-faults-with-incomp',
#   'Abstract': 'Handling missing values and large-dimensional features are crucial requirements for data-driven fault diagnosis systems...',
#   'Date': '26 Nov 2021',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  20: {'Publication title': 'an smt solver for non-linear real arithmetic inside maple',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-smt-solver-for-non-linear-real-arithmetic-inside-maple-2',
#   'Abstract': 'We report on work-in-progress to create an SMT-solver inside Maple for non-linear real arithmetic (NRA)...',
#   'Date': '23 Nov 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  21: {'Publication title': 'an smt solver for non-linear real arithmetic inside maple',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/an-smt-solver-for-non-linear-real-arithmetic-inside-maple',
#   'Abstract': 'not available',
#   'Date': '6 Jul 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  22: {'Publication title': 'artificial intelligence in cars: how close yet far are we from fully autonomous vehicles?',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/artificial-intelligence-in-cars-how-close-yet-far-are-we-from-ful',
#   'Abstract': 'In the last several years, strides in Artificial Intelligence (AI) have allowed for substantial developments in autonomous driving...',
#   'Date': '3 May 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade',
#    'Ankur Deo, https://pureportal.coventry.ac.uk/en/persons/ankur-deo']},
#  23: {'Publication title': 'assessing risks in dairy supply chain systems: a system dynamics approach',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/assessing-risks-in-dairy-supply-chain-systems-a-system-dynamics-a',
#   'Abstract': 'Due to the dynamic nature of the food supply chain system, food supply management could suffer because of, and be interrupted by, unforeseen events...',
#   'Date': '4 Aug 2022',
#   'Author information': ['Maryam Azizsafaei, https://pureportal.coventry.ac.uk/en/persons/maryam-azizsafaei',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  24: {'Publication title': "bispectrum-based cross-frequency functional connectivity: classification of alzheimer's disease",
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/bispectrum-based-cross-frequency-functional-connectivity-classifi',
#   'Abstract': 'Alzheimer’s disease (AD) is a neurodegenerative disease known to affect brain functional connectivity (FC)...',
#   'Date': '8 Sep 2022',
#   'Author information': ['Dominik Klepl, https://pureportal.coventry.ac.uk/en/persons/dominik-klepl',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  25: {'Publication title': 'brain tumor classification using a combination of variational autoencoders and generative adversarial networks',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/brain-tumor-classification-using-a-combination-of-variational-aut',
#   'Abstract': 'Brain tumors are a pernicious cancer with one of the lowest five-year survival rates...',
#   'Date': '21 Jan 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  26: {'Publication title': 'cell site analysis; changes to networks with time',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/cell-site-analysis-changes-to-networks-with-time',
#   'Abstract': 'Cell service areas may change over time as sites or cells are adjusted, decommissioned or introduced, and there may have been changes between the time of calls and the analysis undertaken...',
#   'Date': '6 Apr 2022',
#   'Author information': ['Matthew Stephen Tart, https://pureportal.coventry.ac.uk/en/persons/matthew-stephen-tart']},
#  27: {'Publication title': 'characterising alzheimers disease with eeg-based energy landscape analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/characterising-alzheimers-disease-with-eeg-based-energy-landscape-2',
#   'Abstract': "Alzheimer's disease (AD) is one of the most common neurodegenerative diseases, with around 50 million patients worldwide...",
#   'Date': '18 Aug 2021',
#   'Author information': ['Dominik Klepl, https://pureportal.coventry.ac.uk/en/persons/dominik-klepl',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  28: {'Publication title': 'clogs and shawls: mormons, moorlands, and the search for zion',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/clogs-and-shawls-mormons-moorlands-and-the-search-for-zion',
#   'Abstract': 'not available',
#   'Date': '31 Jan 2022',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford']},
#  29: {'Publication title': 'comparative graph-based summarization of scientific papers guided by comparative citations',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/comparative-graph-based-summarization-of-scientific-papers-guided',
#   'Abstract': 'With the rapid growth of scientific papers, understanding the changes and trends in a research area is rather time-consuming...',
#   'Date': 'Oct 2022',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  30: {'Publication title': 'comparing the behaviour of two topic-modelling algorithms in covid-19 vaccination tweets',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/comparing-the-behaviour-of-two-topic-modelling-algorithms-in-covi',
#   'Abstract': 'Coronavirus is a newly developed infectious disease that has triggered a pandemic due to its ease of transmission as of early 2020...',
#   'Date': 'Jan 2022',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  31: {'Publication title': 'contextualised segment-wise citation function classification',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/contextualised-segment-wise-citation-function-classification',
#   'Abstract': 'Much effort has been made in the past decades to citation function classification...',
#   'Date': '2022',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  32: {'Publication title': 'convolution neural networks for pothole detection of critical road infrastructure',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/convolution-neural-networks-for-pothole-detection-of-critical-roa',
#   'Abstract': 'A well developed and maintained highway infrastructure is essential for the economic and social prosperity of modern societies...',
#   'Date': '16 Feb 2022',
#   'Author information': ['Anup Kumar Pandey, https://pureportal.coventry.ac.uk/en/persons/anup-pandey-2',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  33: {'Publication title': 'data-driven dynamical modelling of a pathogen-infected plant gene regulatory network: a comparative analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/data-driven-dynamical-modelling-of-a-pathogen-infected-plant-gene',
#   'Abstract': 'Recent advances in synthetic biology have enabled the design of genetic feedback control circuits that could be implemented to build resilient plants against pathogen attacks...',
#   'Date': '1 Jul 2022',
#   'Author information': ['Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  34: {'Publication title': 'detection of sleep apnea using machine learning algorithms based on ecg signals: a comprehensive systematic review',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/detection-of-sleep-apnea-using-machine-learning-algorithms-based-',
#   'Abstract': 'Sleep apnea (SA) is a common sleep disorder that is not easy to detect...',
#   'Date': '25 Sep 2021',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  35: {'Publication title': 'differential radial basis function network for sequence modelling',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/differential-radial-basis-function-network-for-sequence-modelling',
#   'Abstract': 'We propose a differential radial basis function (RBF) network termed RBF-DiffNet—whose hidden layer blocks are partial differential equations (PDEs) linear in terms of the RBF—to make the baseline RBF network robust to noise in sequential data...',
#   'Date': '13 Oct 2021',
#   'Author information': ['James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura']},
#  36: {'Publication title': 'edge-enhancement densenet for x-ray fluoroscopy image denoising in cardiac electrophysiology procedures',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/edge-enhancement-densenet-for-x-ray-fluoroscopy-image-denoising-i',
#   'Abstract': 'Purpose: Reducing X-ray dose increases safety in cardiac electrophysiology procedures but also increases image noise and artifacts which may affect the discernibility of devices and anatomical cues...',
#   'Date': '18 Jan 2022',
#   'Author information': ['YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  37: {'Publication title': "eeg-based graph neural network classification of alzheimer's disease: an empirical evaluation of functional connectivity methods",
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/eeg-based-graph-neural-network-classification-of-alzheimers-disea',
#   'Abstract': "Alzheimer's disease (AD) is the leading form of dementia worldwide...",
#   'Date': '6 Sep 2022',
#   'Author information': ['Dominik Klepl, https://pureportal.coventry.ac.uk/en/persons/dominik-klepl',
#    'Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  38: {'Publication title': 'efficacy of covid-19 vaccines by race and ethnicity',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/efficacy-of-covid-19-vaccines-by-race-and-ethnicity',
#   'Abstract': 'Objectives: Vaccine uptake amongst ethnic minority populations has been persistently lower, which may be because of socio-economic factors such as health literacy and health insurance status...',
#   'Date': '5 May 2022',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  39: {'Publication title': 'examining type 1 diabetes mathematical models using experimental data',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/examining-type-1-diabetes-mathematical-models-using-experimental-',
#   'Abstract': 'Type 1 diabetes requires treatment with insulin injections and monitoring glucose levels in affected individuals...',
#   'Date': '10 Jan 2022',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  40: {'Publication title': 'exploiting domain structures in heuristic algorithms for the set covering problem: a literature review',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/exploiting-domain-structures-in-heuristic-algorithms-for-the-set-',
#   'Abstract': 'This review aims at understanding the set covering problem (SCP) as an NP-hard problem, the variants of SCP, the methods that have been proposed to solve the problem, and gaps in the existing solutions that have been provided which need further research...',
#   'Date': '1 Apr 2022',
#   'Author information': ['Abiola Babatunde, https://pureportal.coventry.ac.uk/en/persons/abiola-babatunde']},
#  41: {'Publication title': 'exploring dynamical properties of a type 1 diabetes model using sensitivity approaches',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/exploring-dynamical-properties-of-a-type-1-diabetes-model-using-s',
#   'Abstract': 'The high global prevalence of diabetes, and the extortionate costs imposed on healthcare providers necessitate further research to understand different perspectives of the disease...',
#   'Date': '18 May 2022',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  42: {'Publication title': 'fast, detailed, accurate simulation of a thermal car-cabin using machine-learning',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/fast-detailed-accurate-simulation-of-a-thermal-car-cabin-using-ma',
#   'Abstract': 'Car-cabin thermal systems, including heated seats, air-conditioning, and radiant panels, use a large proportion of the energy budget of electric vehicles and thus reduce their effective range...',
#   'Date': '10 Mar 2022',
#   'Author information': ['Brandi Jo Jess, https://pureportal.coventry.ac.uk/en/persons/brandi-jo-jess',
#    'James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura']},
#  43: {'Publication title': 'feedback and engagement on an introductory programming module',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/feedback-and-engagement-on-an-introductory-programming-module',
#   'Abstract': 'We ran a study on engagement and achievement for a first year undergraduate programming module which  used an online learning environment containing tasks which generate automated feedback...',
#   'Date': '6 Jan 2022',
#   'Author information': ['Beate Grawemeyer, https://pureportal.coventry.ac.uk/en/persons/beate-grawemeyer',
#    'John Halloran, https://pureportal.coventry.ac.uk/en/persons/john-halloran',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  44: {'Publication title': 'framework for generating integrable expressions',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/framework-for-generating-integrable-expressions',
#   'Abstract': 'Applications of machine learning are becoming more prominent in the field of computer algebra...',
#   'Date': '2 Nov 2022',
#   'Author information': ['Rashid Barket, https://pureportal.coventry.ac.uk/en/persons/rashid-barket']},
#  45: {'Publication title': 'from theory to practice: a review of co-design methods for humanitarian energy ecosystems',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/from-theory-to-practice-a-review-of-co-design-methods-for-humanit',
#   'Abstract': 'Our planet is currently in the midst of a global humanitarian crisis...',
#   'Date': '23 Feb 2022',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Gaura, E., https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Crawley, H., https://pureportal.coventry.ac.uk/en/persons/heaven-crawley',
#    'Lim, M., https://pureportal.coventry.ac.uk/en/persons/ming-lim',
#    'Nixon, J., https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon']},
#  46: {'Publication title': 'gaussian process emulation of spatio-temporal outputs of a 2d inland flood model',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/gaussian-process-emulation-of-spatio-temporal-outputs-of-a-2d-inl',
#   'Abstract': 'The computational limitations of complex numerical models have led to adoption of statistical emulators across a variety of problems in science and engineering disciplines to circumvent the high computational costs associated with numerical simulations...',
#   'Date': '14 Sep 2022',
#   'Author information': ['James Donnelly, https://pureportal.coventry.ac.uk/en/persons/james-donnelly',
#    'Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  47: {'Publication title': 'incorporating forecasting and peer-to-peer negotiation frameworks into a distributed model predictive control approach for meshed electric networks',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/incorporating-forecasting-and-peer-to-peer-negotiation-frameworks',
#   'Abstract': 'The continuous integration of renewable energy sources into power networks is causing a paradigm shift in energy generation and distribution with regard to trading and control...',
#   'Date': '15 Mar 2022',
#   'Author information': ['Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura']},
#  48: {'Publication title': 'kac-rice formulas and the number of solutions of parametrized systems of polynomial equations',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/kac-rice-formulas-and-the-number-of-solutions-of-parametrized-sys',
#   'Abstract': 'Kac-Rice formulas express the expected number of elements a fiber of a random field has in terms of a multivariate integral...',
#   'Date': '11 Aug 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  49: {'Publication title': 'levelwise construction of a single cylindrical algebraic cell',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/levelwise-construction-of-a-single-cylindrical-algebraic-cell',
#   'Abstract': 'Satisfiability Modulo Theories (SMT) solvers check the satisfiability of quantifier-free first-order logic formulas...',
#   'Date': '25 Nov 2022',
#   'Author information': ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  50: {'Publication title': 'leveraging arabic sentiment classification using an enhanced cnn-lstm approach and effective arabic text preparation',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/leveraging-arabic-sentiment-classification-using-an-enhanced-cnn-',
#   'Abstract': 'The high variety in the forms of the Arabic words creates significant complexity related challenges in Natural Language Processing (NLP) tasks for Arabic text...',
#   'Date': '27 Dec 2021',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  51: {'Publication title': 'lift: lncrna identification and function-prediction tool',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/lift-lncrna-identification-and-function-prediction-tool',
#   'Abstract': 'Long non-coding RNAs (lncRNAs) are a class of non-coding RNAs which play a significant role in several biological processes...',
#   'Date': '17 Jan 2022',
#   'Author information': ['James Shuttleworth, https://pureportal.coventry.ac.uk/en/persons/james-shuttleworth',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  52: {'Publication title': 'machine learning for computer algebra',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/machine-learning-for-computer-algebra',
#   'Abstract': 'not available',
#   'Date': '2022',
#   'Author information': ['Rashid Barket, https://pureportal.coventry.ac.uk/en/persons/rashid-barket',
#    'Tereso del Río, https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  53: {'Publication title': 'markov chain monte carlo-based estimation of stress–strength reliability parameter for generalized linear failure rate distributions',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/markov-chain-monte-carlo-based-estimation-of-stressstrength-relia',
#   'Abstract': 'This paper provides Bayesian and classical inference of Stress–Strength reliability parameter, [Formula: see text], where both [Formula: see text] and [Formula: see text] are independently distributed as 3-parameter generalized linear failure rate (GLFR) random variables with different parameters...',
#   'Date': '3 Jun 2021',
#   'Author information': ['A. Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  54: {'Publication title': 'matrix decomposition by transforming the unit sphere to an ellipsoid through dilation, rotation and shearing',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/matrix-decomposition-by-transforming-the-unit-sphere-to-an-ellips',
#   'Abstract': 'There are various decompositions of matrices in the literature such as lower-upper, singular value and polar decompositions to name a few...',
#   'Date': '19 Oct 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  55: {'Publication title': 'minimizing age of information in multi-hop energy-harvesting wireless sensor network',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/minimizing-age-of-information-in-multi-hop-energy-harvesting-wire',
#   'Abstract': 'Age of information (AoI), a metric measuring the information freshness, has drawn increased attention due to its importance in monitoring applications in which nodes send time-stamped status updates to interested recipients, and timely updates about phenomena are important...',
#   'Date': '9 Aug 2022',
#   'Author information': ['Fatma Benkhelifa, https://pureportal.coventry.ac.uk/en/persons/fatma-benkhelifa']},
#  56: {'Publication title': 'monte carlo simulation of stochastic differential equation to study information geometry',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/monte-carlo-simulation-of-stochastic-differential-equation-to-stu',
#   'Abstract': 'Information Geometry is a useful tool to study and compare the solutions of a Stochastic Differential Equations (SDEs) for non-equilibrium systems...',
#   'Date': '12 Aug 2022',
#   'Author information': ['Abhiram Anand Thiruthummal, https://pureportal.coventry.ac.uk/en/persons/abhiram-thiruthummal',
#    'Eun-jin Kim, https://pureportal.coventry.ac.uk/en/persons/e-j-kim']},
#  57: {'Publication title': 'more than faith - muslim-heritage children in care: strategic briefing',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/more-than-faith-muslim-heritage-children-in-care-strategic-briefi',
#   'Abstract': 'This briefing aims to support senior managers in meeting the needs of Muslim-heritage children and young people in care...',
#   'Date': '31 May 2022',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
#    'Sariya Cheruvallil-Contractor, https://pureportal.coventry.ac.uk/en/persons/sariya-cheruvallil-contractor']},
#  58: {'Publication title': 'multi-phase locking value: a generalized method for determining instantaneous multi-frequency phase coupling',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/multi-phase-locking-value-a-generalized-method-for-determining-in-2',
#   'Abstract': 'Background: Many physical, biological and neural systems behave as coupled oscillators, with characteristic phase coupling across different frequencies...',
#   'Date': '7 Jan 2022',
#   'Author information': ['Fei He, https://pureportal.coventry.ac.uk/en/persons/fei-he',
#    'He, F., https://pureportal.coventry.ac.uk/en/persons/fei-he']},
#  59: {'Publication title': 'new heuristic to choose a cylindrical algebraic decomposition variable ordering motivated by complexity analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/new-heuristic-to-choose-a-cylindrical-algebraic-decomposition-var',
#   'Abstract': 'It is well known that the variable ordering can be critical to the efficiency or even tractability of the cylindrical algebraic decomposition (CAD) algorithm...',
#   'Date': '11 Aug 2022',
#   'Author information': ['Tereso del Río, https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  60: {'Publication title': 'off the boil? the challenges of monitoring cooking behaviour in refugee settlements',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/off-the-boil-the-challenges-of-monitoring-cooking-behaviour-in-re',
#   'Abstract': 'To address the need for improved access to energy and meet the United Nations Clean Energy Challenge (2019), humanitarian agencies require robust, valid, and meaningful data that documents the everyday energy practices of displaced people...',
#   'Date': '22 Apr 2022',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Jonathan Nixon, https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon']},
#  61: {'Publication title': 'on the impact of prior distributions on efficiency of sparse gaussian process regression',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/on-the-impact-of-prior-distributions-on-efficiency-of-sparse-gaus',
#   'Abstract': 'Gaussian process regression (GPR) is a kernel-based learning model, which unfortunately suffers from computational intractability for irregular domain and large datasets due to the full kernel matrix...',
#   'Date': '26 Jun 2022',
#   'Author information': ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  62: {'Publication title': 'on the implementation of cylindrical algebraic coverings for satisfiability modulo theories solving',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/on-the-implementation-of-cylindrical-algebraic-coverings-for-sati',
#   'Abstract': 'We recently presented cylindrical algebraic coverings: a method based on the theory of cylindrical algebraic decomposition and suited for nonlinear real arithmetic theory reasoning in Satisfiability Modulo Theories solvers...',
#   'Date': '10 Feb 2022',
#   'Author information': ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  63: {'Publication title': 'on the scalability of duty-cycled lora networks with imperfect sf orthogonality',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/on-the-scalability-of-duty-cycled-lora-networks-with-imperfect-sf',
#   'Abstract': 'This letter uses stochastic geometry and queuing theory to study the scalability of long-range (LoRa) networks, accounting for duty cycling restrictions and imperfect spreading factor (SFs) orthogonality...',
#   'Date': '23 Aug 2022',
#   'Author information': ['Fatma Benkhelifa, https://pureportal.coventry.ac.uk/en/persons/fatma-benkhelifa']},
#  64: {'Publication title': 'parallel multi-swarm cooperative particle swarm optimization for protein–ligand docking and virtual screening',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/parallel-multi-swarm-cooperative-particle-swarm-optimization-for-',
#   'Abstract': 'Background: A high-quality docking method tends to yield multifold gains with half pains for the new drug development...',
#   'Date': '30 May 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  65: {'Publication title': 'parts of speech tagging in nlp- an investigation on runtime optimization with quantum formulation and zx calculus',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/parts-of-speech-tagging-in-nlp-an-investigation-on-runtime-optimi',
#   'Abstract': 'This paper presents an optimized formulation of the parts of speech tagging in Natural Language Processing (NLP) with a quantum computing approach, and it further demonstrates the quantum gate-level runnable optimization with ZX-calculus, keeping the implementation target in the context of Noisy Intermediate Scale Quantum Systems (NISQ)...',
#   'Date': '10 Mar 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  66: {'Publication title': 'polynomial superlevel set representation of the multistationarity region of chemical reaction networks',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/polynomial-superlevel-set-representation-of-the-multistationarity',
#   'Abstract': 'In this paper we introduce a new representation for the multistationarity region of a reaction network, using polynomial superlevel sets...',
#   'Date': '27 Sep 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  67: {'Publication title': 'predicting primary sequence-based protein-protein interactions using a mercer series representation of nonlinear support vector machine',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/predicting-primary-sequence-based-protein-protein-interactions-us',
#   'Abstract': 'The prediction of protein-protein interactions (PPIs) is essential to understand the cellular processes from a medical perspective...',
#   'Date': '1 Dec 2022',
#   'Author information': ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  68: {'Publication title': 'predicting the public adoption of connected and autonomous vehicles',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/predicting-the-public-adoption-of-connected-and-autonomous-vehicl',
#   'Abstract': 'Connected and Autonomous Vehicles (CAV) are gaining increasing importance due to the current needs of modern society for better mobility and societal impact...',
#   'Date': '11 Oct 2021',
#   'Author information': ['Mohammed Lawal Ahmed, https://pureportal.coventry.ac.uk/en/persons/mohammed-ahmed',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  69: {'Publication title': 'privacy enhancing technologies (pets) for connected vehicles in smart cities',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/privacy-enhancing-technologies-pets-for-connected-vehicles-in-sma',
#   'Abstract': 'Many Experts believe that the Internet of Things (IoT) is a new revolution in technology that has brought many benefits for our organizations, businesses, and industries...',
#   'Date': '18 Nov 2020',
#   'Author information': ['Faye Mitchell, https://pureportal.coventry.ac.uk/en/persons/faye-mitchell']},
#  70: {'Publication title': 'rapid localization and mapping method based on adaptive particle filters',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/rapid-localization-and-mapping-method-based-on-adaptive-particle-',
#   'Abstract': 'With the development of autonomous vehicles, localization and mapping technologies have become crucial to equip the vehicle with the appropriate knowledge for its operation...',
#   'Date': '2 Dec 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  71: {'Publication title': 'rdpsovina: the random drift particle swarm optimization for protein-ligand docking',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/rdpsovina-the-random-drift-particle-swarm-optimization-for-protei',
#   'Abstract': 'Protein-ligand docking is of great importance to drug design, since it can predict the binding affinity between ligand and protein, and guide the synthesis direction of the lead compounds...',
#   'Date': '9 May 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  72: {'Publication title': 'resilient consensus control design for dc microgrids against false data injection attacks using a distributed bank of sliding mode observers',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/resilient-consensus-control-design-for-dc-microgrids-against-fals',
#   'Abstract': 'This paper investigates the problem of false data injection attack (FDIA) detection in microgrids...',
#   'Date': '30 Mar 2022',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  73: {'Publication title': 'saving research budgets by improving algebraic tools for the study of population dynamics',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/saving-research-budgets-by-improving-algebraic-tools-for-the-stud',
#   'Abstract': 'not available',
#   'Date': '7 Mar 2022',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  74: {'Publication title': 'sc-square: future progress with machine learning',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/sc-square-future-progress-with-machine-learning',
#   'Abstract': 'The algorithms employed by our communities are often underspecified, and thus have multiple implementation choices, which do not effect the correctness of the output, but do impact the efficiency or even tractability of its production...',
#   'Date': '14 Nov 2022',
#   'Author information': ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  75: {'Publication title': 'sc-square: overview to 2021.',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/sc-square-overview-to-2021',
#   'Abstract': 'This extended abstract was written to accompany an invited talk at the 2021 SC-Square Workshop, where the author was asked to give an overview of SC-Square progress to date...',
#   'Date': '14 Nov 2022',
#   'Author information': ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  76: {'Publication title': 'stable likelihood computation for machine learning of linear differential operators with gaussian processes',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/stable-likelihood-computation-for-machine-learning-of-linear-diff',
#   'Abstract': 'In many applied sciences, the main aim is to learn the parameters in the operational equations which best fit the observed data...',
#   'Date': '20 Apr 2022',
#   'Author information': ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  77: {'Publication title': 'switching trackers for effective sensor fusion in advanced driver assistance systems',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/switching-trackers-for-effective-sensor-fusion-in-advanced-driver',
#   'Abstract': 'Modern cars utilise Advanced Driver Assistance Systems (ADAS) in several ways...',
#   'Date': '3 Nov 2022',
#   'Author information': ['Ankur Deo, https://pureportal.coventry.ac.uk/en/persons/ankur-deo',
#    'Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']},
#  78: {'Publication title': 'the benefits of clustering in cylindrical algebraic decomposition',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-benefits-of-clustering-in-cylindrical-algebraic-decomposition',
#   'Abstract': 'Cylindrical Algebraic Decomposition (CAD) is a very powerful algorithm with many potential applications, however, its doubly exponential complexity limits its usability...',
#   'Date': '2022',
#   'Author information': ['Tereso del Río, https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano',
#    'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']},
#  79: {'Publication title': 'the politics of matching: ethnicity, religion and muslim-heritage children in care in the uk',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-politics-of-matching-ethnicity-religion-and-muslim-heritage-c',
#   'Abstract': 'In 2014, in order to improve outcomes for children from ethnic minority backgrounds and to speed up the adoption process, the UK government changed the Children and Families Act...',
#   'Date': '20 Apr 2022',
# ...
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/opinion-evidence-in-cell-site-analysis',
#   'Abstract': 'Issues concerning forensic inference exist in all areas of Forensic Science, and Cell Site Analysis is no exception...',
#   'Date': '26 Feb 2020',
#   'Author information': ['Matthew Stephen Tart, https://pureportal.coventry.ac.uk/en/persons/matthew-stephen-tart']},
#  178: {'Publication title': 'some computational considerations for kernel-based support vector machine',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/some-computational-considerations-for-kernel-based-support-vector',
#   'Abstract': 'Sometimes healthcare perspectives in communications technologies require data mining, especially classification as a supervised learning...',
#   'Date': '2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  179: {'Publication title': 'the empty womb, the unanswered prayer: female infertility and involuntary childlessness in british mormon communities',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-empty-womb-the-unanswered-prayer-female-infertility-and-invol',
#   'Abstract': 'not available',
#   'Date': '28 Dec 2020',
#   'Author information': ['Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford']},
#  180: {'Publication title': 'the impact of physical exercise on the fatigue symptoms in patients with multiple sclerosis: a systematic review and meta-analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-impact-of-physical-exercise-on-the-fatigue-symptoms-in-patien',
#   'Abstract': 'Background: Despite many benefits of the physical activity on physical and mental health of patients with Multiple Sclerosis (MS), the activity level in these patients is still very limited, and they continue to suffer from impairment in functioning ability...',
#   'Date': '13 Mar 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  181: {'Publication title': 'the influence of acclimatization, age and gender-related differences on thermal perception in university buildings: case studies in scotland and england',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-influence-of-acclimatization-age-and-gender-related-differenc',
#   'Abstract': "The higher education sector in the UK is responsible for large amount of the country's energy consumption...",
#   'Date': '8 May 2020',
#   'Author information': ['James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Azadeh Montazami, https://pureportal.coventry.ac.uk/en/persons/azadeh-montazami',
#    'James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Azadeh Montazami, https://pureportal.coventry.ac.uk/en/persons/azadeh-montazami']},
#  182: {'Publication title': 'the prevalence of restless legs syndrome/willis-ekbom disease (rls/wed) in the third trimester of pregnancy: a systematic review',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-prevalence-of-restless-legs-syndromewillis-ekbom-disease-rlsw',
#   'Abstract': 'BACKGROUND: RLS is known as one of the most common movement disorders during pregnancy, which is most aggravated in the third trimester of pregnancy and can affect up to one-third of pregnant women...',
#   'Date': '13 Apr 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  183: {'Publication title': 'the prevalence of severe depression in iranian older adult: a meta-analysis and meta-regression',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-prevalence-of-severe-depression-in-iranian-older-adult-a-meta',
#   'Abstract': 'Background: Depression is one of the most common psychiatric disorders in the older adult and one of the most common risk factors for suicide in the older adult...',
#   'Date': '3 Feb 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  184: {'Publication title': 'the prevalence of sleep disturbances among physicians and nurses facing the covid-19 patients: a systematic review and meta-analysis',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-prevalence-of-sleep-disturbances-among-physicians-and-nurses-',
#   'Abstract': 'Background: In all epidemics, healthcare staff are at the centre of risks and damages caused by pathogens...',
#   'Date': '29 Sep 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  185: {'Publication title': 'the prevalence of stress, anxiety and depression within front-line healthcare workers caring for covid-19 patients: a systematic review and meta-regression',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-prevalence-of-stress-anxiety-and-depression-within-front-line',
#   'Abstract': 'Background Stress, anxiety, and depression are some of the most important research and practice challenges for psychologists, psychiatrists, and behavioral scientists...',
#   'Date': '17 Dec 2020',
#   'Author information': ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  186: {'Publication title': 'understanding household fuel choice behaviour in the amazonas state, brazil: effects of validation and feature selection',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/understanding-household-fuel-choice-behaviour-in-the-amazonas-sta',
#   'Abstract': 'Since 2003, Brazil has striven to provide energy access to all, in rural areas, in an effort to economically empower the communities...',
#   'Date': '28 Jul 2020',
#   'Author information': ['Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'James Brusey, https://pureportal.coventry.ac.uk/en/persons/james-brusey',
#    'Gaura, E., https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Brusey, J., https://pureportal.coventry.ac.uk/en/persons/james-brusey']},
#  187: {'Publication title': 'vehicular localisation at high and low estimation rates during gnss outages: a deep learning approach',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/vehicular-localisation-at-high-and-low-estimation-rates-during-gn',
#   'Abstract': 'Road localisation of autonomous vehicles is reliant on consistent accurate GNSS (Global Navigation Satellite System) positioning information...',
#   'Date': '25 Sep 2020',
#   'Author information': ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade',
#    'Stavros Richard G. Christopoulos, https://pureportal.coventry.ac.uk/en/persons/stavros-christopoulos']},
#  188: {'Publication title': 'cell site analysis: roles and interpretation',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/cell-site-analysis-roles-and-interpretation',
#   'Abstract': 'This paper considers the confusion that exists between opinion and non-opinion evidence concerning telecommunication data – and thus the boundary between expert and technical evidence...',
#   'Date': '6 Jun 2019',
#   'Author information': ['Matthew Stephen Tart, https://pureportal.coventry.ac.uk/en/persons/matthew-stephen-tart']},
#  189: {'Publication title': 'mass transpiration in magneto-hydrodynamic boundary layer flow over a superlinear stretching sheet embedded in porous medium with slip',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/mass-transpiration-in-magneto-hydrodynamic-boundary-layer-flow-ov',
#   'Abstract': 'We have studied mass transpiration of a magneto-hydrodynamic (MHD) flow of a Newtonian fluid over a superlinear stretching sheet embedded in a porous medium...',
#   'Date': '1 Jan 2019',
#   'Author information': ['A. Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  190: {'Publication title': 'remote sensing technologies and energy applications in refugee camps',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/remote-sensing-technologies-and-energy-applications-in-refugee-ca',
#   'Abstract': 'Whilst technological breakthroughs alone cannot revolutionise energy access for refugees, a number of innovations are offering the possibility of transformational change...',
#   'Date': '1 Jan 2019',
#   'Author information': ['Jonathan Daniel Nixon, https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon',
#    'Elena Gaura, https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Gaura, E., https://pureportal.coventry.ac.uk/en/persons/elena-gaura',
#    'Crawley, H., https://pureportal.coventry.ac.uk/en/persons/heaven-crawley',
#    'Lim, M., https://pureportal.coventry.ac.uk/en/persons/ming-lim',
#    'Nixon, J., https://pureportal.coventry.ac.uk/en/persons/jonathan-nixon']},
#  191: {'Publication title': 'spontaneous fruit fly optimisation for truss weight minimisation: performance evaluation based on the no free lunch theorem',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/spontaneous-fruit-fly-optimisation-for-truss-weight-minimisation-',
#   'Abstract': 'Over the past decade, several researchers have presented various optimisation algorithms for use in truss design...',
#   'Date': '24 Sep 2019',
#   'Author information': ['Michael E. Fitzpatrick, https://pureportal.coventry.ac.uk/en/persons/michael-fitzpatrick']},
#  192: {'Publication title': 'the scales project, a cross-national dataset on the interpretation of thermal perception scales',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/the-scales-project-a-cross-national-dataset-on-the-interpretation',
#   'Abstract': 'Thermal discomfort is one of the main triggers for occupants’ interactions with components of the built environment such as adjustments of thermostats and/or opening windows and strongly related to the energy use in buildings...',
#   'Date': '26 Nov 2019',
#   'Author information': ['Montazami Azadeh, https://pureportal.coventry.ac.uk/en/persons/azadeh-montazami']},
#  193: {'Publication title': 'algebraic tools in the study of multistationarity of chemical reaction networks',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/algebraic-tools-in-the-study-of-multistationarity-of-chemical-rea',
#   'Abstract': 'not available',
#   'Date': '31 Oct 2018',
#   'Author information': ['AmirHosein Sadeghimanesh, https://pureportal.coventry.ac.uk/en/persons/amirhosein-sadeghimanesh-sadeghi-manesh']},
#  194: {'Publication title': 'among the last ones to leave? understanding the journeys of muslim children in the care system in england',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/among-the-last-ones-to-leave-understanding-the-journeys-of-muslim',
#   'Abstract': 'Children of Muslim heritage are likely to experience significant delay in finding a fostering or adoptive placement and where a child has complex needs due to health, disability, age, mixed or multiple heritage background or being part of a sibling group, finding permanent placement takes even longer...',
#   'Date': '2018',
#   'Author information': ['Sariya Cheruvallil-Contractor, https://pureportal.coventry.ac.uk/en/persons/sariya-cheruvallil-contractor',
#    'Alison Halford, https://pureportal.coventry.ac.uk/en/persons/alison-halford',
#    'Cheruvallil-Contractor, S., https://pureportal.coventry.ac.uk/en/persons/sariya-cheruvallil-contractor',
#    'Halford, A., https://pureportal.coventry.ac.uk/en/persons/alison-halford']},
#  195: {'Publication title': 'discrete weighted exponential distribution of the second type: properties and applications',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/discrete-weighted-exponential-distribution-of-the-second-type-pro',
#   'Abstract': 'In this paper, we propose a new lifetime model as a discrete version of the continuous weighted exponential distribution which is called discrete weighted exponential distribution (DWED)...',
#   'Date': '2018',
#   'Author information': ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun',
#    'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']},
#  196: {'Publication title': 'h*pt: 一种鼓励质量平衡产量的 h 型指数',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/hpt-an-h-type-index-encouraging-quality-and-balancing-productivit',
#   'Abstract': 'As a balanced indicator for both the quality and productivity of researchers’ scientific outputs, h-index suffers severely from loss of significant information in citation distributions so that its ability to discriminate researchers is rather limited...',
#   'Date': 'Jan 2017',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  197: {'Publication title': '基于城市群的空气质量数据的可视分析方法研究',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/urban-agglomerations-based-visual-analysis-of-air-quality-data',
#   'Abstract': 'Air pollution has gradually become an important issue, and has attracted more and more attention from the general public and the scientific community...',
#   'Date': '15 Mar 2017',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']},
#  198: {'Publication title': 'major differences of cloud computing adoption in universities: europe vs middle east',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/major-differences-of-cloud-computing-adoption-in-universities-eur-2',
#   'Abstract': 'The extensive use of cloud computing in educational institutes around the world brings unique challenges for universities...',
#   'Date': 'Dec 2014',
#   'Author information': ['Kevin Warwick, https://pureportal.coventry.ac.uk/en/persons/kevin-warwick']},
#  199: {'Publication title': 'extraction of cardiac and respiratory motion information from cardiac x-ray fluoroscopy images using hierarchical manifold learning',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/extraction-of-cardiac-and-respiratory-motion-information-from-car',
#   'Abstract': 'We present a novel and clinically useful method to automatically determine the regions that carry cardiac and respiratory motion information directly from standard mono-plane X-ray fluoroscopy images...',
#   'Date': '2013',
#   'Author information': ['YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  200: {'Publication title': 'infarct segmentation challenge on delayed enhancement mri of the left ventricle',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/infarct-segmentation-challenge-on-delayed-enhancement-mri-of-the-',
#   'Abstract': 'This paper presents collated results from the Delayed en-hancement MRI (DE-MRI) segmentation challenge as part of MICCAI 2012...',
#   'Date': '2013',
#   'Author information': ['YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  201: {'Publication title': 'real-time catheter extraction from 2d x-ray fluoroscopic and 3d echocardiographic images for cardiac interventions',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/real-time-catheter-extraction-from-2d-x-ray-fluoroscopic-and-3d-e',
#   'Abstract': 'X-ray fluoroscopic images are widely used for image guidance in cardiac electrophysiology (EP) procedures to diagnose or treat cardiac arrhythmias based on catheter ablation...',
#   'Date': '2013',
#   'Author information': ['YingLiang Ma, https://pureportal.coventry.ac.uk/en/persons/yingliang-ma']},
#  202: {'Publication title': 'adding logical operators to tree pattern queries ongraph-structured data',
#   'Link': 'https://pureportal.coventry.ac.uk/en/publications/adding-logical-operators-to-tree-pattern-queries-ongraph-structur',
#   'Abstract': 'As data are increasingly modeled as graphs for expressing com-plex relationships, the tree pattern query on graph-structured databecomes an important type of queries in real-world applications...',
#   'Date': 'Aug 2012',
#   'Author information': ['Xiaorui Jiang, https://pureportal.coventry.ac.uk/en/persons/xiaorui-jiang']}}

# %%
# combining the tokenised words in cleaned titles to form a cleaned sentence for vectorization
filtered_docs = []
for title in cleaned_titles:
    title = ' '.join(title)
    filtered_docs.append(title)
filtered_docs
# Out:
# ['extend plant circadian clock model characteris flower time differ light qualiti condit',
#  'challeng prospect climat chang impact assess mangrov environ mathemat model',
#  'diabet retinopathi detect use transfer reinforc learn effect imag preprocess data augment techniqu',
#  'lamarckian particl swarm optim flexibl ligand dock',
#  'extract evolutionari backbon scientif domain semant main path network approach base citat context analysi',
#  'gene regulatori network infer link predict use graph neural network',
#  'model mangrov impos tidal wave use finit element discontinu galerkin method',
#  'nonlinear manifold learn eeg function connect analysi applic alzheim diseas',
#  'born woman gender robot',
#  'posenormnet postur normal 3d bodi scan arbitrari postur',
#  'unidirect migrat popul alle effect',
#  'xdll explain deep learn local map method vehicl',
#  'commun energi manag system smart microgrid',
#  'hybrid linear iter cluster bay grabcut segment scheme dynam detect cervic cancer',
#  'alloc medic resourc vaccin control pandem',
#  'optimis approach vehicl rout problem uniqu vehicl locat depot',
#  'effect swarm intellig optim algorithm flexibl ligand dock',
#  'improv gaussian distribut base particl swarm optim algorithm engin shape design problem',
#  'integr framework diagnos process fault incomplet featur',
#  'smt solver real arithmet insid mapl',
#  'smt solver real arithmet insid mapl',
#  'artifici intellig car close yet far fulli autonom vehicl',
#  'assess risk dairi suppli chain system system dynam approach',
#  'function connect classif alzheim diseas',
#  'brain tumor classif use combin variat autoencod gener adversari network',
#  'cell site analysi chang network time',
#  'characteris alzheim diseas energi landscap analysi',
#  'clog shawl mormon moorland search zion',
#  'compar summar scientif paper guid compar citat',
#  'compar behaviour two algorithm vaccin tweet',
#  'contextualis citat function classif',
#  'convolut neural network pothol detect critic road infrastructur',
#  'dynam model plant gene regulatori network compar analysi',
#  'detect sleep apnea use machin learn algorithm base ecg signal comprehens systemat review',
#  'differenti radial basi function network sequenc model',
#  'densenet fluoroscopi imag denois cardiac electrophysiolog procedur',
#  'graph neural network classif alzheim diseas empir evalu function connect method',
#  'efficaci vaccin race ethnic',
#  'examin type 1 diabet mathemat model use experiment data',
#  'exploit domain structur heurist algorithm set cover problem literatur review',
#  'explor dynam properti type 1 diabet model use sensit approach',
#  'fast detail accur simul thermal use',
#  'feedback engag introductori program modul',
#  'framework gener integr express',
#  'theori practic review method humanitarian energi ecosystem',
#  'gaussian process emul output 2d inland flood model',
#  'incorpor forecast negoti framework distribut model predict control approach mesh electr network',
#  'formula number solut parametr system polynomi equat',
#  'levelwis construct singl cylindr algebra cell',
#  'leverag arab sentiment classif use enhanc approach effect arab text prepar',
#  'lift lncrna identif tool',
#  'machin learn comput algebra',
#  'markov chain mont estim reliabl paramet gener linear failur rate distribut',
#  'matrix decomposit transform unit sphere ellipsoid dilat rotat shear',
#  'minim age inform wireless sensor network',
#  'mont carlo simul stochast differenti equat studi inform geometri',
#  'faith children care strateg brief',
#  'lock valu gener method determin instantan phase coupl',
#  'new heurist choos cylindr algebra decomposit variabl order motiv complex analysi',
#  'boil challeng monitor cook behaviour refuge settlement',
#  'impact prior distribut effici spars gaussian process regress',
#  'implement cylindr algebra cover satisfi modulo theori solv',
#  'scalabl lora network imperfect sf orthogon',
#  'parallel cooper particl swarm optim dock virtual screen',
#  'part speech tag investig runtim optim quantum formul zx calculu',
#  'polynomi superlevel set represent multistationar region chemic reaction network',
#  'predict primari interact use mercer seri represent nonlinear support vector machin',
#  'predict public adopt connect autonom vehicl',
#  'privaci enhanc technolog pet connect vehicl smart citi',
#  'rapid local map method base adapt particl filter',
#  'rdpsovina random drift particl swarm optim dock',
#  'resili consensu control design dc microgrid fals data inject attack use distribut bank slide mode observ',
#  'save research budget improv algebra tool studi popul dynam',
#  'futur progress machin learn',
#  'overview 2021',
#  'stabl likelihood comput machin learn linear differenti oper gaussian process',
#  'switch tracker effect sensor fusion advanc driver assist system',
#  'benefit cluster cylindr algebra decomposit',
#  'polit match ethnic religion children care uk',
#  'practic ai ethic energi transit futur',
#  'transfer learn base classif diabet retinopathi kaggl eyepac dataset',
#  'trustworthi systemat review autom interview coventri univers',
#  'use machin learn anomali detect gamma radiat',
#  'use machin learn anomali detect gamma radiat',
#  'use machin learn sc2',
#  'use optimis adm1 measur data improv perform exist anaerob digest system',
#  'use neural network model mangrov environ',
#  'word represent use refin context',
#  'access point select strategi indoor 5g distribut antenna system',
#  'adversari learn incomplet imbalanc medic data robust surviv predict liver transplant patient',
#  'implement map hardwar',
#  'hybrid framework brain tissu segment magnet reson imag',
#  'hybrid framework detect elimin power grid',
#  'regular particl filter estim ambigu sensor fault',
#  'analysi standalon solar streetlight improv energi access displac settlement',
#  'empir studi span model scienc ner',
#  'new fuzzi optimis system manag contain yard oper',
#  'new method segment satellit imag',
#  'improv fuzzi model long stay contain yard',
#  'probabilist predict model assess econom reusabl build compon develop circular economi framework',
#  'quaternion gate recurr unit neural network sensor fusion',
#  'review collis avoid system unman aerial vehicl',
#  'time seri base studi correl channel power imbal divers gain indoor distribut antenna system 60 ghz',
#  'function connect studi alzheim diseas',
#  'build capac heed skill audit recommend heed skill audit recommend',
#  'cell site analysi use reliabl survey method',
#  'centralis decentralis sensor emerg brake assist',
#  'characteris alzheim diseas energi landscap analysi',
#  'polici brief 1 citizen scienc add valu investig complianc gener data protect regul gdpr',
#  'right privaci onlin',
#  'decid consist real arithmet constraint conflict driven search use cylindr algebra cover',
#  'divers collabor guid random drift particl swarm optim',
#  'particl swarm optim algorithm base decomposit divers control',
#  'econom evalu mental health effect flood use bayesian network',
#  'effici activ recognit use lightweight cnn network surveil applic',
#  'ensur energi accuraci awar schedul heterogen system',
#  'evalu switch combin base distribut antenna system da commun',
#  'find uncomfort solut respons innov humanitarian energi',
#  'gener pedestrian cross scenario use gener adversari network',
#  'gener adversari scheme diagnos fault power system',
#  'guest editori special issu deep represent transfer learn smart connect health',
#  'improv algebra tool studi bifurc sequenc popul model',
#  'improv skin cancer classif use student gener adversari network',
#  'investig effect two fragranc comfort automot context',
#  'light seamless highway light system',
#  'inerti odometri benchmark dataset ground vehicl posit',
#  'learn localis autom vehicl challeng environ use inerti navig system in',
#  'learn uncertainti wheel odometri vehicular localis gnss depriv environ',
#  'measur local sensit bayesian infer use new class metric',
#  'mobil comput disast evacu techniqu guidanc support survey',
#  'msldock optim flexibl ligand dock virtual screen',
#  'lock valu gener method determin instantan phase coupl',
#  'nonlinear estim sensor fault unknown dynam fix wing unman aerial vehicl',
#  'nonlinear system identif neural system neurophysiolog signal',
#  'novel fault mitig approach soc recoveri',
#  'optimis feedstock flowrat improv perform exist anaerob digest system',
#  'pedestrian vehicl detect autonom vehicl percept review',
#  'predict mortal durat treatment pulmonari embol requir ceil ventilatori support inpati approach',
#  'predict technic reusabl build compon probabilist approach toward develop circular economi framework',
#  'prove unsat smt case quantifi free real arithmet',
#  'registr 3d echo fluoroscopi base cascad classifi imag registr',
#  'scenario optimis sensit analysi safe autom drive use gaussian process',
#  'secur improv energi harvest base overlay cognit network destin',
#  'simultan actuat sensor fault estim aircraft use regular particl filter',
#  'ssf smart citi semant framework reusabl semant data',
#  'challeng solar energi intervent lesson two rwandan refuge camp',
#  'dewcad project push back doubli exponenti wall cylindr algebra decomposit',
#  'salienc islam muslim heritag children experi ident famili foster care',
#  'topic model precis medicin applic person diabet manag',
#  'toward physic equilibrium model comput',
#  'unpack gender sexual contemporari mormon',
#  'unsupervis doppler radar base activ recognit',
#  'use machin learn algorithm develop clinic tool inpati',
#  'whonet wheel odometri neural network vehicular localis environ',
#  'work toward modern afford sustain energi system context displac recommend research practition',
#  'come follow sacralis home guardian famili european women negoti domest space church jesu christ saint',
#  'leap random quantum cluster support vector machin comput complex analysi',
#  'low cost highli accur techniqu big data interpol',
#  'machin learn base softwar pipelin pick variabl order algorithm polynomi input',
#  'new hardwar approach map',
#  'scalabl hybrid mac strategi network',
#  'behaviour analyt prevent mean futur polic',
#  'construct gene regulatori network microarray data use bayesian network',
#  'contemporari issu church jesu christ saint ireland unit kingdom',
#  'probabilist assess intens durat cold episod case studi malay vineyard region',
#  'digit twin technolog smart citi',
#  'effect capac analysi gener composit fade channel',
#  'energi optim joint task comput use genet algorithm',
#  'evalu assumpt scale subject assess thermal environ layperson perceiv way research believ',
#  'farm area segment satellit imag use neural network',
#  'gener pedestrian pose structur use gener adversari network',
#  'indoor visibl light commun tutori survey',
#  'inerti odometri benchmark dataset ground vehicl posit',
#  'nonlinear system identif neural system neurophysiolog signal',
#  'shadow fade model',
#  'function central limit theorem first passag time nonlinear reward process',
#  'opinion evid cell site analysi',
#  'comput consider support vector machin',
#  'empti womb unansw prayer femal infertil involuntari childless british mormon commun',
#  'impact physic exercis fatigu symptom patient multipl sclerosi systemat review',
#  'influenc acclimat age differ thermal percept univers build case studi scotland england',
#  'preval restless leg diseas third trimest pregnanc systemat review',
#  'preval sever depress iranian older adult',
#  'preval sleep disturb among physician nurs face patient systemat review',
#  'preval stress anxieti depress within healthcar worker care patient systemat review',
#  'understand household fuel choic behaviour amazona state brazil effect valid featur select',
#  'vehicular localis high low estim rate gnss outag deep learn approach',
#  'cell site analysi role interpret',
#  'mass transpir boundari layer flow superlinear stretch sheet embed porou medium slip',
#  'remot sens technolog energi applic refuge camp',
#  'spontan fruit fli optimis truss weight minimis perform evalu base free lunch theorem',
#  'scale project dataset interpret thermal percept scale',
#  'algebra tool studi multistationar chemic reaction network',
#  'among last one leav understand journey muslim children care system england',
#  'discret weight exponenti distribut second type properti applic',
#  'h pt 一种鼓励质量平衡产量的 h 型指数',
#  '基于城市群的空气质量数据的可视分析方法研究',
#  'major differ cloud comput adopt univers europ vs middl east',
#  'extract cardiac respiratori motion inform cardiac fluoroscopi imag use hierarch manifold learn',
#  'infarct segment challeng delay enhanc mri left ventricl',
#  'cathet extract 2d fluoroscop 3d echocardiograph imag cardiac intervent',
#  'ad logic oper tree pattern queri data']

# %%
# combining the tokenised words in cleaned titles to form a cleaned sentence for vectorization
filtered_docs = []
for title in cleaned_titles:
    title = ' '.join(title)
    filtered_docs.append(title)
filtered_docs

def queryprocessor(query):
    tokens = word_tokenize(query)
    tmp = ""
    for w in tokens:
        if w not in stopwords.words('english'):
            tmp += ps.stem(w) + " "

    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(filtered_docs) # vectorization of the document
    query_vec = vectorizer.transform([tmp]) # vectorization of query
    results = cosine_similarity(X,query_vec).reshape((-1,)) # to measure document similary
    res = results.tolist()
    similarity_data = {'doc_id': docid, 'similarity_score': res, 'title': data_titles}
    df_similarity = pd.DataFrame(similarity_data) # dataframe to visualise the similarity of the query to each doc
    df_similarity.sort_values(by=['similarity_score'], inplace=True, ascending=False) # values arranged in ascending order
    query_relevance = df_similarity[df_similarity['similarity_score'] > 0] #only similarity values > 0 printed
    post_lists = (query_relevance['doc_id']).tolist()

    # retrieves publication details based on doc ID from post list
    if post_lists:
        for i in post_lists:
            idd = i
            for id, info in data_dict.items():
                if idd == id:
                    print()
                    for key in info:
                        result = print(key + ':', info[key])
    else:
        print('please try searching another term or phrase')

    return post_lists, results, query_relevance

user_input = input('Query: ')
post_lists, results, query_relevance = queryprocessor(user_input)
# Out:
# Query: machine learnin
#
# Publication title: machine learning for computer algebra
# Link: https://pureportal.coventry.ac.uk/en/publications/machine-learning-for-computer-algebra
# Abstract: not available
# Date: 2022
# Author information: ['Rashid Barket, https://pureportal.coventry.ac.uk/en/persons/rashid-barket', 'Tereso del Río, https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano', 'Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']
#
# Publication title: using machine learning in sc2
# Link: https://pureportal.coventry.ac.uk/en/publications/using-machine-learning-in-sc2
# Abstract: This talk exposes many possible uses of Machine Learning (ML) in the context of SC2, and how this approach differs from human-made heuristics...
# Date: 23 Aug 2022
# Author information: ['Tereso del Río, https://pureportal.coventry.ac.uk/en/persons/tereso-del-r%C3%ADo-almajano']
#
# Publication title: sc-square: future progress with machine learning
# Link: https://pureportal.coventry.ac.uk/en/publications/sc-square-future-progress-with-machine-learning
# Abstract: The algorithms employed by our communities are often underspecified, and thus have multiple implementation choices, which do not effect the correctness of the output, but do impact the efficiency or even tractability of its production...
# Date: 14 Nov 2022
# Author information: ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']
#
# Publication title: some computational considerations for kernel-based support vector machine
# Link: https://pureportal.coventry.ac.uk/en/publications/some-computational-considerations-for-kernel-based-support-vector
# Abstract: Sometimes healthcare perspectives in communications technologies require data mining, especially classification as a supervised learning...
# Date: 2020
# Author information: ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']
#
# Publication title: using machine learning for anomaly detection on a system-on-chip under gamma radiation
# Link: https://pureportal.coventry.ac.uk/en/publications/using-machine-learning-for-anomaly-detection-on-a-system-on-chip--2
# Abstract: The emergence of new nanoscale technologies has imposed significant challenges to designing reliable electronic systems in radiation environments...
# Date: 30 Jun 2022
# Author information: ['Server Kasap, https://pureportal.coventry.ac.uk/en/persons/server-kasap', 'Kasap, S., https://pureportal.coventry.ac.uk/en/persons/server-kasap']
#
# Publication title: using machine learning for anomaly detection on a system-on-chip under gamma radiation
# Link: https://pureportal.coventry.ac.uk/en/publications/using-machine-learning-for-anomaly-detection-on-a-system-on-chip-
# Abstract: The emergence of new nanoscale technologies has imposed significant challenges to designing reliable electronic systems in radiation environments...
# Date: 5 Jan 2022
# Author information: ['Server Kasap, https://pureportal.coventry.ac.uk/en/persons/server-kasap', 'Kasap, S., https://pureportal.coventry.ac.uk/en/persons/server-kasap']
#
# Publication title: using machine learning algorithms to develop a clinical decision-making tool for covid-19 inpatients
# Link: https://pureportal.coventry.ac.uk/en/publications/using-machine-learning-algorithms-to-develop-a-clinical-decision-
# Abstract: Background: Within the UK, COVID-19 has contributed towards over 103,000 deaths...
# Date: 9 Jun 2021
# Author information: ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']
#
# Publication title: stable likelihood computation for machine learning of linear differential operators with gaussian processes
# Link: https://pureportal.coventry.ac.uk/en/publications/stable-likelihood-computation-for-machine-learning-of-linear-diff
# Abstract: In many applied sciences, the main aim is to learn the parameters in the operational equations which best fit the observed data...
# Date: 20 Apr 2022
# Author information: ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun', 'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']
#
# Publication title: a leap from randomized to quantum clustering with support vector machine - a computation complexity analysis
# Link: https://pureportal.coventry.ac.uk/en/publications/a-leap-from-randomized-to-quantum-clustering-with-support-vector-
# Abstract: Supervised machine learning deals with developing complex non-linear models, which can be used later to predict the output for a known input...
# Date: 3 Aug 2020
# Author information: ['Vasile Palade, https://pureportal.coventry.ac.uk/en/persons/vasile-palade']
#
# Publication title: predicting primary sequence-based protein-protein interactions using a mercer series representation of nonlinear support vector machine
# Link: https://pureportal.coventry.ac.uk/en/publications/predicting-primary-sequence-based-protein-protein-interactions-us
# Abstract: The prediction of protein-protein interactions (PPIs) is essential to understand the cellular processes from a medical perspective...
# Date: 1 Dec 2022
# Author information: ['Omid Chatrabgoun, https://pureportal.coventry.ac.uk/en/persons/omid-chatrabgoun', 'Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']
#
# Publication title: a machine learning based software pipeline to pick the variable ordering for algorithms with polynomial inputs
# Link: https://pureportal.coventry.ac.uk/en/publications/a-machine-learning-based-software-pipeline-to-pick-the-variable-o
# Abstract: We are interested in the application of Machine Learning (ML) technology to improve mathematical software...
# Date: 8 Jul 2020
# Author information: ['Matthew England, https://pureportal.coventry.ac.uk/en/persons/matthew-england']
#
# Publication title: detection of sleep apnea using machine learning algorithms based on ecg signals: a comprehensive systematic review
# Link: https://pureportal.coventry.ac.uk/en/publications/detection-of-sleep-apnea-using-machine-learning-algorithms-based-
# Abstract: Sleep apnea (SA) is a common sleep disorder that is not easy to detect...
# Date: 25 Sep 2021
# Author information: ['Alireza Daneshkhah, https://pureportal.coventry.ac.uk/en/persons/alireza-daneshkhah']

# %%
query_relevance
# Out:
#      doc_id  similarity_score  \
# 51       52          0.495055
# 84       85          0.467051
# 73       74          0.416693
# 177     178          0.361861
# 82       83          0.327064
# 83       84          0.327064
# 152     153          0.303623
# 75       76          0.254152
# 156     157          0.250876
# 66       67          0.238679
# 158     159          0.232619
# 33       34          0.232470
#
#                                                  title
# 51               machine learning for computer algebra
# 84                       using machine learning in sc2
# 73    sc-square: future progress with machine learning
# 177  some computational considerations for kernel-b...
# 82   using machine learning for anomaly detection o...
# 83   using machine learning for anomaly detection o...
# 152  using machine learning algorithms to develop a...
# 75   stable likelihood computation for machine lear...
# 156  a leap from randomized to quantum clustering w...
# 66   predicting primary sequence-based protein-prot...
# 158  a machine learning based software pipeline to ...
# 33   detection of sleep apnea using machine learnin...
